# %%
import os
import sagemaker

sagemaker_session = sagemaker.Session()

bucket = 'calvinandpogs-ee148'

role = sagemaker.get_execution_role()
print(bucket, role)
print(os.getcwd())

# %%
from sagemaker.pytorch import PyTorch

estimator = PyTorch(entry_point='./atrwtool/main.py',
                    source_dir='./',
                    framework_version='1.8.0',
                    role=role,
                    py_version='py3',
                    instance_count=1,
                    instance_type='ml.g4dn.xlarge',
                    hyperparameters={
                        'task': 'detection',
                        'input': 'SM_CHANNEL_RESULTS/best_predictions.json'
                    })

# %%
estimator.fit({'results': f's3://{bucket}/models/yolov5/train-full/'})
# Out:
# 2021-05-22 02:56:05 Starting - Starting the training job...
# 2021-05-22 02:56:27 Starting - Launching requested ML instancesProfilerReport-1621652113: InProgress
# ......
# 2021-05-22 02:57:28 Starting - Preparing the instances for training......
# 2021-05-22 02:58:33 Downloading - Downloading input data......
# 2021-05-22 02:59:31 Training - Downloading the training image...............
# 2021-05-22 03:01:59 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-05-22 03:01:59,596 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-05-22 03:01:59,617 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-05-22 03:02:02,639 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-05-22 03:02:04,335 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "annot": "/opt/ml/input/data/annot",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "annot": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-05-22-02-55-13-649",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-22-02-55-13-649/source/sourcedir.tar.gz",
#     "module_name": "YOLO-mini-tiger/main",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "YOLO-mini-tiger/main.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=YOLO-mini-tiger/main.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"annot":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["annot","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=YOLO-mini-tiger/main
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-22-02-55-13-649/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"annot":"/opt/ml/input/data/annot","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"annot":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-05-22-02-55-13-649","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-22-02-55-13-649/source/sourcedir.tar.gz","module_name":"YOLO-mini-tiger/main","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"YOLO-mini-tiger/main.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_ANNOT=/opt/ml/input/data/annot
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 YOLO-mini-tiger/main.py
#
#
# /opt/ml/code/YOLO-mini-tiger/darknet/data/tiger
# Completed 208.7 KiB/208.7 KiB (1.5 MiB/s) with 1 file(s) remaining
# upload: data/tiger/2007_train.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/train2019.txt
# Completed 23.3 KiB/23.3 KiB (214.7 KiB/s) with 1 file(s) remaining
# upload: data/tiger/2007_val.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/valid2019.txt
# ++ date +%m-%d-%y-%H-%M-%S
# + S3_BASE=s3://calvinandpogs-ee148/atrw/detection/out/05-22-21-03-02-04
# + DN_BASE=darknet/data/tiger/VOCdevkit/VOC2007
# + git clone https://github.com/AlexeyAB/darknet
# Cloning into 'darknet'...
# + rm darknet/Makefile
# + cp -r darknet_files/Makefile darknet_files/cfg darknet_files/data darknet/
# + mkdir -p darknet/data/tiger/VOCdevkit/VOC2007
# + ln -s /opt/ml/input/data/annot/Annotations darknet/data/tiger/VOCdevkit/VOC2007/Annotations
# + ln -s /opt/ml/input/data/annot/ImageSets darknet/data/tiger/VOCdevkit/VOC2007/ImageSets
# + ln -s /opt/ml/input/data/train darknet/data/tiger/VOCdevkit/VOC2007/JPEGImages
# + cd darknet
# + cd data/tiger
# + python voc_label.py
# + cd ../..
# + aws s3 cp data/tiger/2007_train.txt s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/train2019.txt
# + aws s3 cp data/tiger/2007_val.txt s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/valid2019.txt
#
# 2021-05-22 03:02:08,333 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-05-22 03:02:29 Uploading - Uploading generated training model
# 2021-05-22 03:02:29 Completed - Training job completed
# Training seconds: 220
# Billable seconds: 220

# %%
# Out:
# WARNING:sagemaker.deprecations:The function delete_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
