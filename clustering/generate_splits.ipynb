# %%
import os
import sagemaker

sagemaker_session = sagemaker.Session()

bucket = 'calvinandpogs-ee148'

role = sagemaker.get_execution_role()
print(bucket, role)
print(os.getcwd())
# Out:
# calvinandpogs-ee148 arn:aws:iam::652516965730:role/service-role/AmazonSageMaker-ExecutionRole-20210513T011299
# /home/ec2-user/SageMaker/atrw/util/clustering

# %%
from sagemaker.tensorflow import TensorFlow

estimator = TensorFlow(entry_point='cluster_split.py',
                        source_dir='./',
                        role=role,
                        instance_count=1,
                        instance_type="ml.g4dn.xlarge",
                        framework_version="2.2",
                        py_version="py37",
                        hyperparameters={
                            'output-s3': 's3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/'
                        })

# %%
estimator.fit({'clusters': f's3://{bucket}/atrw/detection/annotations/clusters/vgg16places/umap-spectral-md01/labels'})
# Out:
# 2021-06-02 10:23:26 Starting - Starting the training job...
# 2021-06-02 10:23:50 Starting - Launching requested ML instancesProfilerReport-1622629405: InProgress
# ......
# 2021-06-02 10:24:55 Starting - Preparing the instances for training.........
# 2021-06-02 10:26:10 Downloading - Downloading input data
# 2021-06-02 10:26:10 Training - Downloading the training image......
# 2021-06-02 10:27:24 Training - Training image download completed. Training in progress..2021-06-02 10:27:24.927787: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# 2021-06-02 10:27:24.931428: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:106] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-06-02 10:27:25.037366: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:425] Initializing the SageMaker Profiler.
# ...
