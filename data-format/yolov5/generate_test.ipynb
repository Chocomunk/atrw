# %%
import os
import sagemaker

sagemaker_session = sagemaker.Session()

bucket = 'calvinandpogs-ee148'

role = sagemaker.get_execution_role()
print(bucket, role)
print(os.getcwd())
# Out:
# calvinandpogs-ee148 arn:aws:iam::652516965730:role/service-role/AmazonSageMaker-ExecutionRole-20210513T011299
# /home/ec2-user/SageMaker/atrw/data-format/yolov5

# %%
from sagemaker.pytorch import PyTorch

estimator = PyTorch(entry_point='coco2voc_label.py',
                    source_dir='./',
                    framework_version='1.8.0',
                    role=role,
                    py_version='py3',
                    instance_count=1,
                    instance_type='ml.g4dn.xlarge',
                    hyperparameters={})

# %%
estimator.fit({'unused': f's3://{bucket}/atrw/detection/annotations/voc/ImageSets'})
# Out:
# 2021-05-25 07:35:13 Starting - Starting the training job...
# 2021-05-25 07:35:38 Starting - Launching requested ML instancesProfilerReport-1621928112: InProgress
# .........
# 2021-05-25 07:36:58 Starting - Preparing the instances for training......
# 2021-05-25 07:38:01 Downloading - Downloading input data...
# 2021-05-25 07:38:38 Training - Downloading the training image..................
# 2021-05-25 07:41:45 Uploading - Uploading generated training modelbash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-05-25 07:41:35,457 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-05-25 07:41:35,486 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-05-25 07:41:41,717 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-05-25 07:41:42,135 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "unused": "/opt/ml/input/data/unused"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "unused": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-05-25-07-35-12-874",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-25-07-35-12-874/source/sourcedir.tar.gz",
#     "module_name": "coco2voc_label",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "coco2voc_label.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=coco2voc_label.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"unused":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["unused"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=coco2voc_label
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-25-07-35-12-874/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"unused":"/opt/ml/input/data/unused"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"unused":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-05-25-07-35-12-874","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-25-07-35-12-874/source/sourcedir.tar.gz","module_name":"coco2voc_label","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"coco2voc_label.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_UNUSED=/opt/ml/input/data/unused
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 coco2voc_label.py
#
#
# Traceback (most recent call last):
#   File "coco2voc_label.py", line 85, in <module>
#     main()
#   File "coco2voc_label.py", line 78, in main
#     write_annots(annots, image_set, image_set_dir, labels_dir)
#   File "coco2voc_label.py", line 43, in write_annots
#     for img_id, img_data in annot_dict.values:
# TypeError: 'builtin_function_or_method' object is not iterable
#
# 2021-05-25 07:41:42,215 sagemaker-training-toolkit ERROR    ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 coco2voc_label.py"
# Traceback (most recent call last):
#   File "coco2voc_label.py", line 85, in <module>
#     main()
#   File "coco2voc_label.py", line 78, in main
#     write_annots(annots, image_set, image_set_dir, labels_dir)
#   File "coco2voc_label.py", line 43, in write_annots
#     for img_id, img_data in annot_dict.values:
# TypeError: 'builtin_function_or_method' object is not iterable
#
# 2021-05-25 07:42:01 Failed - Training job failed
# ProfilerReport-1621928112: Stopping
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-4-57e43b0fb15b> in <module>
# ----> 1 estimator.fit({'unused': f's3://{bucket}/atrw/detection/annotations/voc/ImageSets'})
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     670         self.jobs.append(self.latest_training_job)
#     671         if wait:
# --> 672             self.latest_training_job.wait(logs=logs)
#     673
#     674     def _compilation_job_name(self):
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#    1601         # If logs are requested, call logs_for_jobs.
#    1602         if logs != "None":
# -> 1603             self.sagemaker_session.logs_for_job(self.job_name, wait=True, log_type=logs)
#    1604         else:
#    1605             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll, log_type)
#    3659
#    3660         if wait:
# -> 3661             self._check_job_status(job_name, description, "TrainingJobStatus")
#    3662             if dot:
#    3663                 print()
#
# ~/anaconda3/envs/pytorch_latest_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    3231                 ),
#    3232                 allowed_statuses=["Completed", "Stopped"],
# -> 3233                 actual_status=status,
#    3234             )
#    3235
#
# UnexpectedStatusException: Error for Training job pytorch-training-2021-05-25-07-35-12-874: Failed. Reason: AlgorithmError: ExecuteUserScriptError:
# Command "/opt/conda/bin/python3.6 coco2voc_label.py"
# Traceback (most recent call last):
#   File "coco2voc_label.py", line 85, in <module>
#     main()
#   File "coco2voc_label.py", line 78, in main
#     write_annots(annots, image_set, image_set_dir, labels_dir)
#   File "coco2voc_label.py", line 43, in write_annots
#     for img_id, img_data in annot_dict.values:
# TypeError: 'builtin_function_or_method' object is not iterable
