# %%
import os
import sagemaker

sagemaker_session = sagemaker.Session()

bucket = 'calvinandpogs-ee148'

role = sagemaker.get_execution_role()
print(bucket, role)
print(os.getcwd())
# Out:
# calvinandpogs-ee148 arn:aws:iam::652516965730:role/service-role/AmazonSageMaker-ExecutionRole-20210513T011299
# /home/ec2-user/SageMaker/atrw/data-format/yolov5

# %%
from sagemaker.pytorch import PyTorch

estimator = PyTorch(entry_point='voc_label.py',
                    source_dir='./',
                    framework_version='1.8.0',
                    role=role,
                    py_version='py3',
                    instance_count=1,
                    instance_type='ml.g4dn.xlarge',
                    hyperparameters={})

# %%
estimator.fit({'annot': f's3://{bucket}/atrw/detection/annotations/voc/'})
# Out:
# 2021-05-23 00:51:45 Starting - Starting the training job...
# 2021-05-23 00:52:07 Starting - Launching requested ML instancesProfilerReport-1621731104: InProgress
# ......
# 2021-05-23 00:53:14 Starting - Preparing the instances for training.........
# 2021-05-23 00:54:32 Downloading - Downloading input data......
# 2021-05-23 00:55:28 Training - Downloading the training image.............bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-05-23 00:57:49,014 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-05-23 00:57:49,034 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-05-23 00:57:50,458 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-05-23 00:57:50,941 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "annot": "/opt/ml/input/data/annot"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "annot": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-05-23-00-51-44-024",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-23-00-51-44-024/source/sourcedir.tar.gz",
#     "module_name": "voc_label",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "voc_label.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=voc_label.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"annot":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["annot"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=voc_label
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-23-00-51-44-024/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"annot":"/opt/ml/input/data/annot"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"annot":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-05-23-00-51-44-024","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-23-00-51-44-024/source/sourcedir.tar.gz","module_name":"voc_label","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"voc_label.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_ANNOT=/opt/ml/input/data/annot
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 voc_label.py
#
#
# Completed 70.4 KiB/~78.2 KiB (920.9 KiB/s) with ~2 file(s) remaining (calculating...)
# upload: yolov5/ImageSets/train.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/ImageSets/train.txt
# Completed 70.4 KiB/~78.2 KiB (920.9 KiB/s) with ~1 file(s) remaining (calculating...)
# Completed 78.2 KiB/~78.2 KiB (897.3 KiB/s) with ~1 file(s) remaining (calculating...)
# upload: yolov5/ImageSets/val.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/ImageSets/val.txt
# Completed 78.2 KiB/~78.2 KiB (897.3 KiB/s) with ~0 file(s) remaining (calculating...)
# Completed 78.3 KiB/~80.9 KiB (595.8 KiB/s) with ~20 file(s) remaining (calculating...)
# upload: yolov5/labels/0000.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0000.txt
# Completed 78.3 KiB/~80.9 KiB (595.8 KiB/s) with ~19 file(s) remaining (calculating...)
# Completed 78.4 KiB/~82.5 KiB (509.1 KiB/s) with ~28 file(s) remaining (calculating...)
# upload: yolov5/labels/0002.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0002.txt
# Completed 78.4 KiB/~82.5 KiB (509.1 KiB/s) with ~27 file(s) remaining (calculating...)
# Completed 78.4 KiB/~83.2 KiB (471.3 KiB/s) with ~34 file(s) remaining (calculating...)
# upload: yolov5/labels/0010.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0010.txt
# Completed 78.4 KiB/~83.2 KiB (471.3 KiB/s) with ~33 file(s) remaining (calculating...)
# Completed 78.6 KiB/~86.2 KiB (429.5 KiB/s) with ~54 file(s) remaining (calculating...)
# upload: yolov5/labels/0013.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0013.txt
# Completed 78.6 KiB/~86.2 KiB (429.5 KiB/s) with ~53 file(s) remaining (calculating...)
# Completed 78.6 KiB/~89.6 KiB (393.4 KiB/s) with ~70 file(s) remaining (calculating...)
# upload: yolov5/labels/0006.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0006.txt
# Completed 78.6 KiB/~89.6 KiB (393.4 KiB/s) with ~69 file(s) remaining (calculating...)
# Completed 78.7 KiB/~89.8 KiB (385.0 KiB/s) with ~73 file(s) remaining (calculating...)
# upload: yolov5/labels/0009.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0009.txt
# Completed 78.7 KiB/~89.8 KiB (385.0 KiB/s) with ~72 file(s) remaining (calculating...)
# Completed 78.8 KiB/~89.8 KiB (382.4 KiB/s) with ~72 file(s) remaining (calculating...)
# upload: yolov5/labels/0005.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0005.txt
# Completed 78.8 KiB/~89.8 KiB (382.4 KiB/s) with ~71 file(s) remaining (calculating...)
# Completed 78.9 KiB/~89.9 KiB (379.6 KiB/s) with ~72 file(s) remaining (calculating...)
# upload: yolov5/labels/0012.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0012.txt
# Completed 78.9 KiB/~90.0 KiB (379.6 KiB/s) with ~72 file(s) remaining (calculating...)
# Completed 79.0 KiB/~90.0 KiB (377.3 KiB/s) with ~72 file(s) remaining (calculating...)
# upload: yolov5/labels/0003.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0003.txt
# Completed 79.0 KiB/~90.0 KiB (377.3 KiB/s) with ~71 file(s) remaining (calculating...)
# Completed 79.1 KiB/~90.0 KiB (374.7 KiB/s) with ~71 file(s) remaining (calculating...)
# upload: yolov5/labels/0015.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0015.txt
# Completed 79.1 KiB/~90.0 KiB (374.7 KiB/s) with ~70 file(s) remaining (calculating...)
# Completed 79.2 KiB/~90.0 KiB (373.5 KiB/s) with ~70 file(s) remaining (calculating...)
# upload: yolov5/labels/0011.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0011.txt
# Completed 79.2 KiB/~90.0 KiB (373.5 KiB/s) with ~69 file(s) remaining (calculating...)
# Completed 79.3 KiB/~90.1 KiB (367.4 KiB/s) with ~70 file(s) remaining (calculating...)
# upload: yolov5/labels/0016.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0016.txt
# Completed 79.3 KiB/~90.1 KiB (367.4 KiB/s) with ~69 file(s) remaining (calculating...)
# Completed 79.4 KiB/~94.0 KiB (328.3 KiB/s) with ~98 file(s) remaining (calculating...)
# upload: yolov5/labels/0018.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0018.txt
# Completed 79.4 KiB/~94.0 KiB (328.3 KiB/s) with ~97 file(s) remaining (calculating...)
# Completed 79.5 KiB/~94.0 KiB (325.9 KiB/s) with ~97 file(s) remaining (calculating...)
# upload: yolov5/labels/0004.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0004.txt
# Completed 79.5 KiB/~94.0 KiB (325.9 KiB/s) with ~96 file(s) remaining (calculating...)
# Completed 79.6 KiB/~94.1 KiB (320.9 KiB/s) with ~97 file(s) remaining (calculating...)
# upload: yolov5/labels/0008.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0008.txt
# Completed 79.6 KiB/~94.1 KiB (320.9 KiB/s) with ~96 file(s) remaining (calculating...)
# Completed 80.2 KiB/~94.1 KiB (321.9 KiB/s) with ~96 file(s) remaining (calculating...)
# upload: yolov5/labels/0019.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0019.txt
# Completed 80.2 KiB/~94.1 KiB (321.9 KiB/s) with ~95 file(s) remaining (calculating...)
# Completed 80.2 KiB/~94.7 KiB (314.7 KiB/s) with ~99 file(s) remaining (calculating...)
# upload: yolov5/labels/0028.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0028.txt
# Completed 80.2 KiB/~94.7 KiB (314.7 KiB/s) with ~98 file(s) remaining (calculating...)
# Completed 80.4 KiB/~95.7 KiB (309.9 KiB/s) with ~105 file(s) remaining (calculating...)
# upload: yolov5/labels/0027.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0027.txt
# Completed 80.4 KiB/~95.7 KiB (309.9 KiB/s) with ~104 file(s) remaining (calculating...)
# Completed 80.4 KiB/~96.0 KiB (305.1 KiB/s) with ~105 file(s) remaining (calculating...)
# upload: yolov5/labels/0026.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0026.txt
# Completed 80.4 KiB/~96.0 KiB (305.1 KiB/s) with ~104 file(s) remaining (calculating...)
# Completed 80.7 KiB/~96.0 KiB (302.6 KiB/s) with ~105 file(s) remaining (calculating...)
# upload: yolov5/labels/0023.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0023.txt
# Completed 80.7 KiB/~96.0 KiB (302.6 KiB/s) with ~104 file(s) remaining (calculating...)
# Completed 80.9 KiB/~97.0 KiB (291.9 KiB/s) with ~111 file(s) remaining (calculating...)
# upload: yolov5/labels/0022.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0022.txt
# Completed 80.9 KiB/~97.0 KiB (291.9 KiB/s) with ~110 file(s) remaining (calculating...)
# Completed 81.1 KiB/~97.4 KiB (287.7 KiB/s) with ~113 file(s) remaining (calculating...)
# upload: yolov5/labels/0025.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0025.txt
# Completed 81.1 KiB/~97.4 KiB (287.7 KiB/s) with ~112 file(s) remaining (calculating...)
# Completed 81.4 KiB/~97.4 KiB (287.4 KiB/s) with ~112 file(s) remaining (calculating...)
# upload: yolov5/labels/0030.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0030.txt
# Completed 81.4 KiB/~97.4 KiB (287.4 KiB/s) with ~111 file(s) remaining (calculating...)
# Completed 81.5 KiB/~97.4 KiB (284.4 KiB/s) with ~111 file(s) remaining (calculating...)
# upload: yolov5/labels/0031.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0031.txt
# Completed 81.5 KiB/~97.4 KiB (284.4 KiB/s) with ~110 file(s) remaining (calculating...)
# Completed 81.5 KiB/~98.2 KiB (281.2 KiB/s) with ~113 file(s) remaining (calculating...)
# upload: yolov5/labels/0033.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0033.txt
# Completed 81.5 KiB/~98.2 KiB (281.2 KiB/s) with ~112 file(s) remaining (calculating...)
# Completed 81.6 KiB/~98.3 KiB (279.8 KiB/s) with ~113 file(s) remaining (calculating...)
# upload: yolov5/labels/0035.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0035.txt
# Completed 81.6 KiB/~98.3 KiB (279.8 KiB/s) with ~112 file(s) remaining (calculating...)
# Completed 81.9 KiB/~98.3 KiB (278.8 KiB/s) with ~112 file(s) remaining (calculating...)
# upload: yolov5/labels/0029.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0029.txt
# Completed 81.9 KiB/~98.3 KiB (278.8 KiB/s) with ~111 file(s) remaining (calculating...)
# Completed 81.9 KiB/~98.4 KiB (277.4 KiB/s) with ~113 file(s) remaining (calculating...)
# upload: yolov5/labels/0038.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0038.txt
# Completed 81.9 KiB/~98.4 KiB (277.4 KiB/s) with ~112 file(s) remaining (calculating...)
# Completed 82.0 KiB/~98.4 KiB (275.1 KiB/s) with ~112 file(s) remaining (calculating...)
# upload: yolov5/labels/0036.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0036.txt
# Completed 82.0 KiB/~98.4 KiB (275.1 KiB/s) with ~111 file(s) remaining (calculating...)
# Completed 82.6 KiB/~99.9 KiB (267.2 KiB/s) with ~119 file(s) remaining (calculating...)
# upload: yolov5/labels/0037.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0037.txt
# Completed 82.6 KiB/~99.9 KiB (267.2 KiB/s) with ~118 file(s) remaining (calculating...)
# Completed 82.6 KiB/~100.0 KiB (262.6 KiB/s) with ~119 file(s) remaining (calculating...)
# upload: yolov5/labels/0043.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0043.txt
# Completed 82.6 KiB/~100.0 KiB (262.6 KiB/s) with ~118 file(s) remaining (calculating...)
# Completed 82.7 KiB/~101.5 KiB (255.0 KiB/s) with ~127 file(s) remaining (calculating...)
# upload: yolov5/labels/0046.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0046.txt
# Completed 82.7 KiB/~101.5 KiB (255.0 KiB/s) with ~126 file(s) remaining (calculating...)
# Completed 82.8 KiB/~101.5 KiB (254.0 KiB/s) with ~126 file(s) remaining (calculating...)
# upload: yolov5/labels/0044.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0044.txt
# Completed 82.8 KiB/~101.5 KiB (254.0 KiB/s) with ~125 file(s) remaining (calculating...)
# Completed 83.1 KiB/~101.6 KiB (253.9 KiB/s) with ~126 file(s) remaining (calculating...)
# upload: yolov5/labels/0042.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0042.txt
# Completed 83.1 KiB/~101.6 KiB (253.9 KiB/s) with ~125 file(s) remaining (calculating...)
# Completed 83.1 KiB/~101.9 KiB (249.3 KiB/s) with ~127 file(s) remaining (calculating...)
# upload: yolov5/labels/0045.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0045.txt
# Completed 83.1 KiB/~101.9 KiB (249.3 KiB/s) with ~126 file(s) remaining (calculating...)
# Completed 83.2 KiB/~102.0 KiB (247.3 KiB/s) with ~128 file(s) remaining (calculating...)
# upload: yolov5/labels/0049.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0049.txt
# Completed 83.2 KiB/~102.0 KiB (247.3 KiB/s) with ~127 file(s) remaining (calculating...)
# Completed 83.3 KiB/~102.1 KiB (244.4 KiB/s) with ~128 file(s) remaining (calculating...)
# upload: yolov5/labels/0052.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0052.txt
# Completed 83.3 KiB/~102.1 KiB (244.4 KiB/s) with ~127 file(s) remaining (calculating...)
# Completed 83.4 KiB/~102.1 KiB (243.2 KiB/s) with ~127 file(s) remaining (calculating...)
# upload: yolov5/labels/0050.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0050.txt
# Completed 83.4 KiB/~102.1 KiB (243.2 KiB/s) with ~126 file(s) remaining (calculating...)
# Completed 83.6 KiB/~102.9 KiB (235.4 KiB/s) with ~133 file(s) remaining (calculating...)
# upload: yolov5/labels/0056.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0056.txt
# Completed 83.6 KiB/~102.9 KiB (235.4 KiB/s) with ~132 file(s) remaining (calculating...)
# Completed 83.7 KiB/~102.9 KiB (231.0 KiB/s) with ~132 file(s) remaining (calculating...)
# upload: yolov5/labels/0054.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0054.txt
# Completed 83.7 KiB/~102.9 KiB (231.0 KiB/s) with ~131 file(s) remaining (calculating...)
# Completed 83.8 KiB/~102.9 KiB (230.2 KiB/s) with ~131 file(s) remaining (calculating...)
# upload: yolov5/labels/0058.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0058.txt
# Completed 83.8 KiB/~103.0 KiB (230.2 KiB/s) with ~131 file(s) remaining (calculating...)
# Completed 83.9 KiB/~103.0 KiB (228.6 KiB/s) with ~132 file(s) remaining (calculating...)
# upload: yolov5/labels/0055.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0055.txt
# Completed 83.9 KiB/~103.0 KiB (228.6 KiB/s) with ~131 file(s) remaining (calculating...)
# Completed 84.1 KiB/~104.4 KiB (220.7 KiB/s) with ~139 file(s) remaining (calculating...)
# upload: yolov5/labels/0059.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0059.txt
# Completed 84.1 KiB/~104.4 KiB (220.7 KiB/s) with ~138 file(s) remaining (calculating...)
# Completed 84.1 KiB/~104.9 KiB (216.1 KiB/s) with ~144 file(s) remaining (calculating...)
# upload: yolov5/labels/0066.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0066.txt
# Completed 84.1 KiB/~104.9 KiB (216.1 KiB/s) with ~143 file(s) remaining (calculating...)
# Completed 84.2 KiB/~105.7 KiB (215.2 KiB/s) with ~149 file(s) remaining (calculating...)
# upload: yolov5/labels/0064.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0064.txt
# Completed 84.2 KiB/~105.7 KiB (215.2 KiB/s) with ~148 file(s) remaining (calculating...)
# Completed 84.6 KiB/~105.7 KiB (215.3 KiB/s) with ~148 file(s) remaining (calculating...)
# upload: yolov5/labels/0060.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0060.txt
# Completed 84.6 KiB/~105.7 KiB (215.3 KiB/s) with ~147 file(s) remaining (calculating...)
# Completed 84.7 KiB/~105.7 KiB (214.9 KiB/s) with ~147 file(s) remaining (calculating...)
# upload: yolov5/labels/0061.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0061.txt
# Completed 84.7 KiB/~105.7 KiB (214.9 KiB/s) with ~146 file(s) remaining (calculating...)
# Completed 84.7 KiB/~105.9 KiB (214.3 KiB/s) with ~147 file(s) remaining (calculating...)
# upload: yolov5/labels/0067.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0067.txt
# Completed 84.7 KiB/~105.9 KiB (214.3 KiB/s) with ~146 file(s) remaining (calculating...)
# Completed 84.9 KiB/~105.9 KiB (214.3 KiB/s) with ~146 file(s) remaining (calculating...)
# upload: yolov5/labels/0062.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0062.txt
# Completed 84.9 KiB/~105.9 KiB (214.3 KiB/s) with ~145 file(s) remaining (calculating...)
# Completed 85.0 KiB/~105.9 KiB (211.6 KiB/s) with ~145 file(s) remaining (calculating...)
# upload: yolov5/labels/0070.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0070.txt
# Completed 85.0 KiB/~105.9 KiB (211.6 KiB/s) with ~144 file(s) remaining (calculating...)
# Completed 85.1 KiB/~106.1 KiB (211.1 KiB/s) with ~145 file(s) remaining (calculating...)
# upload: yolov5/labels/0068.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0068.txt
# Completed 85.1 KiB/~106.1 KiB (211.1 KiB/s) with ~144 file(s) remaining (calculating...)
# Completed 85.1 KiB/~106.1 KiB (209.3 KiB/s) with ~144 file(s) remaining (calculating...)
# upload: yolov5/labels/0071.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0071.txt
# Completed 85.1 KiB/~106.1 KiB (209.3 KiB/s) with ~143 file(s) remaining (calculating...)
# Completed 85.2 KiB/~108.1 KiB (199.8 KiB/s) with ~158 file(s) remaining (calculating...)
# upload: yolov5/labels/0072.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0072.txt
# Completed 85.2 KiB/~108.1 KiB (199.8 KiB/s) with ~157 file(s) remaining (calculating...)
# Completed 85.3 KiB/~109.4 KiB (197.6 KiB/s) with ~161 file(s) remaining (calculating...)
# upload: yolov5/labels/0078.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0078.txt
# Completed 85.3 KiB/~109.4 KiB (197.6 KiB/s) with ~160 file(s) remaining (calculating...)
# Completed 85.4 KiB/~111.3 KiB (193.8 KiB/s) with ~170 file(s) remaining (calculating...)
# upload: yolov5/labels/0073.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0073.txt
# Completed 85.4 KiB/~111.3 KiB (193.8 KiB/s) with ~169 file(s) remaining (calculating...)
# Completed 85.4 KiB/~111.3 KiB (193.3 KiB/s) with ~169 file(s) remaining (calculating...)
# Completed 85.9 KiB/~111.3 KiB (194.2 KiB/s) with ~169 file(s) remaining (calculating...)
# upload: yolov5/labels/0074.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0074.txt
# Completed 85.9 KiB/~111.3 KiB (194.2 KiB/s) with ~168 file(s) remaining (calculating...)
# upload: yolov5/labels/0085.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0085.txt
# Completed 85.9 KiB/~111.3 KiB (194.2 KiB/s) with ~167 file(s) remaining (calculating...)
# Completed 86.0 KiB/~111.5 KiB (193.3 KiB/s) with ~169 file(s) remaining (calculating...)
# upload: yolov5/labels/0081.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0081.txt
# Completed 86.0 KiB/~111.5 KiB (193.3 KiB/s) with ~168 file(s) remaining (calculating...)
# Completed 86.7 KiB/~111.5 KiB (194.0 KiB/s) with ~168 file(s) remaining (calculating...)
# upload: yolov5/labels/0075.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0075.txt
# Completed 86.7 KiB/~111.5 KiB (194.0 KiB/s) with ~167 file(s) remaining (calculating...)
# Completed 87.4 KiB/~112.5 KiB (194.0 KiB/s) with ~171 file(s) remaining (calculating...)
# upload: yolov5/labels/0083.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0083.txt
# Completed 87.4 KiB/~112.5 KiB (194.0 KiB/s) with ~170 file(s) remaining (calculating...)
# Completed 87.5 KiB/~112.9 KiB (191.3 KiB/s) with ~172 file(s) remaining (calculating...)
# upload: yolov5/labels/0086.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0086.txt
# Completed 87.5 KiB/~112.9 KiB (191.3 KiB/s) with ~171 file(s) remaining (calculating...)
# Completed 87.5 KiB/~112.9 KiB (190.9 KiB/s) with ~171 file(s) remaining (calculating...)
# upload: yolov5/labels/0080.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0080.txt
# Completed 87.5 KiB/~112.9 KiB (190.9 KiB/s) with ~170 file(s) remaining (calculating...)
# Completed 87.6 KiB/~113.2 KiB (190.6 KiB/s) with ~171 file(s) remaining (calculating...)
# upload: yolov5/labels/0079.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0079.txt
# Completed 87.6 KiB/~113.2 KiB (190.6 KiB/s) with ~170 file(s) remaining (calculating...)
# Completed 88.3 KiB/~114.2 KiB (186.6 KiB/s) with ~176 file(s) remaining (calculating...)
# upload: yolov5/labels/0088.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0088.txt
# Completed 88.3 KiB/~114.2 KiB (186.6 KiB/s) with ~175 file(s) remaining (calculating...)
# Completed 88.3 KiB/~114.4 KiB (185.2 KiB/s) with ~177 file(s) remaining (calculating...)
# upload: yolov5/labels/0089.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0089.txt
# Completed 88.3 KiB/~114.4 KiB (185.2 KiB/s) with ~176 file(s) remaining (calculating...)
# Completed 88.4 KiB/~115.3 KiB (182.8 KiB/s) with ~183 file(s) remaining (calculating...)
# upload: yolov5/labels/0091.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0091.txt
# Completed 88.4 KiB/~115.3 KiB (182.8 KiB/s) with ~182 file(s) remaining (calculating...)
# Completed 88.5 KiB/~115.3 KiB (181.9 KiB/s) with ~182 file(s) remaining (calculating...)
# upload: yolov5/labels/0096.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0096.txt
# Completed 88.5 KiB/~115.3 KiB (181.9 KiB/s) with ~181 file(s) remaining (calculating...)
# Completed 88.6 KiB/~116.0 KiB (180.1 KiB/s) with ~186 file(s) remaining (calculating...)
# upload: yolov5/labels/0093.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0093.txt
# Completed 88.6 KiB/~116.0 KiB (180.1 KiB/s) with ~185 file(s) remaining (calculating...)
# Completed 88.8 KiB/~116.8 KiB (177.1 KiB/s) with ~191 file(s) remaining (calculating...)
# upload: yolov5/labels/0095.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0095.txt
# Completed 88.8 KiB/~116.8 KiB (177.1 KiB/s) with ~190 file(s) remaining (calculating...)
# Completed 88.9 KiB/~116.8 KiB (177.0 KiB/s) with ~190 file(s) remaining (calculating...)
# upload: yolov5/labels/0100.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0100.txt
# Completed 88.9 KiB/~116.8 KiB (177.0 KiB/s) with ~189 file(s) remaining (calculating...)
# Completed 89.0 KiB/~116.8 KiB (176.7 KiB/s) with ~189 file(s) remaining (calculating...)
# upload: yolov5/labels/0098.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0098.txt
# Completed 89.0 KiB/~116.8 KiB (176.7 KiB/s) with ~188 file(s) remaining (calculating...)
# Completed 89.1 KiB/~117.1 KiB (175.5 KiB/s) with ~190 file(s) remaining (calculating...)
# upload: yolov5/labels/0101.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0101.txt
# Completed 89.1 KiB/~117.1 KiB (175.5 KiB/s) with ~189 file(s) remaining (calculating...)
# Completed 89.1 KiB/~117.5 KiB (174.4 KiB/s) with ~191 file(s) remaining (calculating...)
# upload: yolov5/labels/0104.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0104.txt
# Completed 89.1 KiB/~117.5 KiB (174.4 KiB/s) with ~190 file(s) remaining (calculating...)
# Completed 89.2 KiB/~117.7 KiB (172.9 KiB/s) with ~191 file(s) remaining (calculating...)
# upload: yolov5/labels/0110.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0110.txt
# Completed 89.2 KiB/~117.7 KiB (172.9 KiB/s) with ~190 file(s) remaining (calculating...)
# Completed 89.6 KiB/~117.7 KiB (172.5 KiB/s) with ~190 file(s) remaining (calculating...)
# upload: yolov5/labels/0099.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0099.txt
# Completed 89.6 KiB/~117.7 KiB (172.5 KiB/s) with ~189 file(s) remaining (calculating...)
# Completed 89.6 KiB/~117.7 KiB (171.6 KiB/s) with ~189 file(s) remaining (calculating...)
# upload: yolov5/labels/0107.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0107.txt
# Completed 89.6 KiB/~117.7 KiB (171.6 KiB/s) with ~188 file(s) remaining (calculating...)
# Completed 89.8 KiB/~118.1 KiB (171.0 KiB/s) with ~190 file(s) remaining (calculating...)
# upload: yolov5/labels/0092.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0092.txt
# Completed 89.8 KiB/~118.1 KiB (171.0 KiB/s) with ~189 file(s) remaining (calculating...)
# Completed 89.8 KiB/~118.6 KiB (168.1 KiB/s) with ~192 file(s) remaining (calculating...)
# upload: yolov5/labels/0112.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0112.txt
# Completed 89.8 KiB/~118.6 KiB (168.1 KiB/s) with ~191 file(s) remaining (calculating...)
# Completed 89.9 KiB/~119.0 KiB (167.5 KiB/s) with ~196 file(s) remaining (calculating...)
# upload: yolov5/labels/0113.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0113.txt
# Completed 89.9 KiB/~119.0 KiB (167.5 KiB/s) with ~195 file(s) remaining (calculating...)
# Completed 90.0 KiB/~119.8 KiB (166.1 KiB/s) with ~197 file(s) remaining (calculating...)
# upload: yolov5/labels/0114.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0114.txt
# Completed 90.0 KiB/~119.8 KiB (166.1 KiB/s) with ~196 file(s) remaining (calculating...)
# Completed 90.1 KiB/~119.8 KiB (165.7 KiB/s) with ~196 file(s) remaining (calculating...)
# upload: yolov5/labels/0126.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0126.txt
# Completed 90.1 KiB/~119.8 KiB (165.7 KiB/s) with ~195 file(s) remaining (calculating...)
# Completed 90.1 KiB/~120.1 KiB (164.8 KiB/s) with ~197 file(s) remaining (calculating...)
# upload: yolov5/labels/0125.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0125.txt
# Completed 90.1 KiB/~120.1 KiB (164.8 KiB/s) with ~196 file(s) remaining (calculating...)
# Completed 90.2 KiB/~120.1 KiB (164.2 KiB/s) with ~196 file(s) remaining (calculating...)
# upload: yolov5/labels/0122.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0122.txt
# Completed 90.2 KiB/~120.1 KiB (164.2 KiB/s) with ~195 file(s) remaining (calculating...)
# Completed 90.3 KiB/~121.1 KiB (160.9 KiB/s) with ~202 file(s) remaining (calculating...)
# upload: yolov5/labels/0132.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0132.txt
# Completed 90.3 KiB/~121.1 KiB (160.9 KiB/s) with ~201 file(s) remaining (calculating...)
# Completed 90.5 KiB/~121.2 KiB (160.9 KiB/s) with ~202 file(s) remaining (calculating...)
# upload: yolov5/labels/0130.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0130.txt
# Completed 90.5 KiB/~121.2 KiB (160.9 KiB/s) with ~201 file(s) remaining (calculating...)
# Completed 90.6 KiB/~121.6 KiB (159.7 KiB/s) with ~203 file(s) remaining (calculating...)
# upload: yolov5/labels/0137.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0137.txt
# Completed 90.6 KiB/~121.6 KiB (159.7 KiB/s) with ~202 file(s) remaining (calculating...)
# Completed 90.8 KiB/~121.7 KiB (159.1 KiB/s) with ~203 file(s) remaining (calculating...)
# upload: yolov5/labels/0136.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0136.txt
# Completed 90.8 KiB/~121.7 KiB (159.1 KiB/s) with ~202 file(s) remaining (calculating...)
# Completed 90.9 KiB/~122.2 KiB (158.2 KiB/s) with ~207 file(s) remaining (calculating...)
# upload: yolov5/labels/0131.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0131.txt
# Completed 90.9 KiB/~122.2 KiB (158.2 KiB/s) with ~206 file(s) remaining (calculating...)
# Completed 91.0 KiB/~122.2 KiB (157.0 KiB/s) with ~206 file(s) remaining (calculating...)
# upload: yolov5/labels/0138.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0138.txt
# Completed 91.0 KiB/~122.2 KiB (157.0 KiB/s) with ~205 file(s) remaining (calculating...)
# Completed 91.4 KiB/~122.5 KiB (157.1 KiB/s) with ~208 file(s) remaining (calculating...)
# upload: yolov5/labels/0133.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0133.txt
# Completed 91.4 KiB/~122.5 KiB (157.1 KiB/s) with ~207 file(s) remaining (calculating...)
# Completed 91.6 KiB/~122.5 KiB (156.2 KiB/s) with ~207 file(s) remaining (calculating...)
# upload: yolov5/labels/0139.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0139.txt
# Completed 91.6 KiB/~122.5 KiB (156.2 KiB/s) with ~206 file(s) remaining (calculating...)
# Completed 91.7 KiB/~122.5 KiB (155.7 KiB/s) with ~207 file(s) remaining (calculating...)
# upload: yolov5/labels/0145.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0145.txt
# Completed 91.7 KiB/~122.5 KiB (155.7 KiB/s) with ~206 file(s) remaining (calculating...)
# Completed 91.7 KiB/~124.0 KiB (152.7 KiB/s) with ~216 file(s) remaining (calculating...)
# upload: yolov5/labels/0146.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0146.txt
# Completed 91.7 KiB/~124.0 KiB (152.7 KiB/s) with ~215 file(s) remaining (calculating...)
# Completed 91.8 KiB/~124.9 KiB (151.8 KiB/s) with ~218 file(s) remaining (calculating...)
# upload: yolov5/labels/0120.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0120.txt
# Completed 91.8 KiB/~124.9 KiB (151.8 KiB/s) with ~217 file(s) remaining (calculating...)
# Completed 91.9 KiB/~124.9 KiB (151.4 KiB/s) with ~217 file(s) remaining (calculating...)
# upload: yolov5/labels/0148.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0148.txt
# Completed 91.9 KiB/~124.9 KiB (151.4 KiB/s) with ~216 file(s) remaining (calculating...)
# Completed 91.9 KiB/~125.1 KiB (150.3 KiB/s) with ~218 file(s) remaining (calculating...)
# upload: yolov5/labels/0154.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0154.txt
# Completed 91.9 KiB/~125.1 KiB (150.3 KiB/s) with ~217 file(s) remaining (calculating...)
# Completed 92.0 KiB/~125.6 KiB (150.0 KiB/s) with ~218 file(s) remaining (calculating...)
# upload: yolov5/labels/0152.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0152.txt
# Completed 92.0 KiB/~125.6 KiB (150.0 KiB/s) with ~217 file(s) remaining (calculating...)
# Completed 92.1 KiB/~126.1 KiB (148.8 KiB/s) with ~221 file(s) remaining (calculating...)
# upload: yolov5/labels/0153.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0153.txt
# Completed 92.1 KiB/~126.1 KiB (148.8 KiB/s) with ~220 file(s) remaining (calculating...)
# Completed 92.2 KiB/~126.3 KiB (148.4 KiB/s) with ~221 file(s) remaining (calculating...)
# upload: yolov5/labels/0141.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0141.txt
# Completed 92.2 KiB/~126.3 KiB (148.4 KiB/s) with ~220 file(s) remaining (calculating...)
# Completed 92.6 KiB/~126.5 KiB (147.6 KiB/s) with ~222 file(s) remaining (calculating...)
# upload: yolov5/labels/0147.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0147.txt
# Completed 92.6 KiB/~126.5 KiB (147.6 KiB/s) with ~221 file(s) remaining (calculating...)
# Completed 92.8 KiB/~127.4 KiB (146.1 KiB/s) with ~227 file(s) remaining (calculating...)
# upload: yolov5/labels/0155.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0155.txt
# Completed 92.8 KiB/~127.4 KiB (146.1 KiB/s) with ~226 file(s) remaining (calculating...)
# Completed 92.9 KiB/~128.2 KiB (145.5 KiB/s) with ~229 file(s) remaining (calculating...)
# upload: yolov5/labels/0163.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0163.txt
# Completed 92.9 KiB/~128.2 KiB (145.5 KiB/s) with ~228 file(s) remaining (calculating...)
# Completed 93.0 KiB/~128.9 KiB (144.2 KiB/s) with ~232 file(s) remaining (calculating...)
# upload: yolov5/labels/0158.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0158.txt
# Completed 93.0 KiB/~128.9 KiB (144.2 KiB/s) with ~231 file(s) remaining (calculating...)
# Completed 93.2 KiB/~129.0 KiB (144.1 KiB/s) with ~232 file(s) remaining (calculating...)
# upload: yolov5/labels/0143.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0143.txt
# Completed 93.2 KiB/~129.0 KiB (144.1 KiB/s) with ~231 file(s) remaining (calculating...)
# Completed 93.2 KiB/~129.0 KiB (143.7 KiB/s) with ~231 file(s) remaining (calculating...)
# upload: yolov5/labels/0168.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0168.txt
# Completed 93.2 KiB/~129.0 KiB (143.7 KiB/s) with ~230 file(s) remaining (calculating...)
# Completed 93.5 KiB/~129.0 KiB (143.2 KiB/s) with ~230 file(s) remaining (calculating...)
# upload: yolov5/labels/0165.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0165.txt
# Completed 93.5 KiB/~129.1 KiB (143.2 KiB/s) with ~230 file(s) remaining (calculating...)
# Completed 93.7 KiB/~129.1 KiB (142.9 KiB/s) with ~230 file(s) remaining (calculating...)
# upload: yolov5/labels/0166.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0166.txt
# Completed 93.7 KiB/~129.1 KiB (142.9 KiB/s) with ~229 file(s) remaining (calculating...)
# Completed 93.8 KiB/~129.2 KiB (142.7 KiB/s) with ~230 file(s) remaining (calculating...)
# upload: yolov5/labels/0167.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0167.txt
# Completed 93.8 KiB/~129.2 KiB (142.7 KiB/s) with ~229 file(s) remaining (calculating...)
# Completed 93.9 KiB/~131.3 KiB (140.3 KiB/s) with ~242 file(s) remaining (calculating...)
# upload: yolov5/labels/0169.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0169.txt
# Completed 93.9 KiB/~131.3 KiB (140.3 KiB/s) with ~241 file(s) remaining (calculating...)
# Completed 94.0 KiB/~131.4 KiB (139.9 KiB/s) with ~242 file(s) remaining (calculating...)
# upload: yolov5/labels/0171.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0171.txt
# Completed 94.0 KiB/~131.4 KiB (139.9 KiB/s) with ~241 file(s) remaining (calculating...)
# Completed 94.0 KiB/~131.9 KiB (138.6 KiB/s) with ~245 file(s) remaining (calculating...)
# upload: yolov5/labels/0172.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0172.txt
# Completed 94.0 KiB/~131.9 KiB (138.6 KiB/s) with ~244 file(s) remaining (calculating...)
# Completed 94.1 KiB/~132.8 KiB (136.9 KiB/s) with ~254 file(s) remaining (calculating...)
# upload: yolov5/labels/0173.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0173.txt
# Completed 94.1 KiB/~132.8 KiB (136.9 KiB/s) with ~253 file(s) remaining (calculating...)
# Completed 94.4 KiB/~133.0 KiB (136.5 KiB/s) with ~255 file(s) remaining (calculating...)
# upload: yolov5/labels/0174.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0174.txt
# Completed 94.4 KiB/~133.0 KiB (136.5 KiB/s) with ~254 file(s) remaining (calculating...)
# Completed 94.5 KiB/~133.3 KiB (135.7 KiB/s) with ~256 file(s) remaining (calculating...)
# upload: yolov5/labels/0175.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0175.txt
# Completed 94.5 KiB/~133.3 KiB (135.7 KiB/s) with ~255 file(s) remaining (calculating...)
# Completed 94.8 KiB/~133.3 KiB (135.9 KiB/s) with ~255 file(s) remaining (calculating...)
# upload: yolov5/labels/0180.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0180.txt
# Completed 94.8 KiB/~133.3 KiB (135.9 KiB/s) with ~254 file(s) remaining (calculating...)
# Completed 95.0 KiB/~133.3 KiB (135.8 KiB/s) with ~254 file(s) remaining (calculating...)
# upload: yolov5/labels/0177.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0177.txt
# Completed 95.0 KiB/~133.3 KiB (135.8 KiB/s) with ~253 file(s) remaining (calculating...)
# Completed 95.1 KiB/~134.3 KiB (134.0 KiB/s) with ~261 file(s) remaining (calculating...)
# upload: yolov5/labels/0182.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0182.txt
# Completed 95.1 KiB/~134.3 KiB (134.0 KiB/s) with ~260 file(s) remaining (calculating...)
# Completed 95.2 KiB/~134.3 KiB (133.9 KiB/s) with ~260 file(s) remaining (calculating...)
# upload: yolov5/labels/0183.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0183.txt
# Completed 95.2 KiB/~134.3 KiB (133.9 KiB/s) with ~259 file(s) remaining (calculating...)
# Completed 95.4 KiB/~134.6 KiB (133.0 KiB/s) with ~263 file(s) remaining (calculating...)
# upload: yolov5/labels/0181.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0181.txt
# Completed 95.4 KiB/~134.6 KiB (133.0 KiB/s) with ~262 file(s) remaining (calculating...)
# Completed 95.5 KiB/~134.6 KiB (132.9 KiB/s) with ~262 file(s) remaining (calculating...)
# upload: yolov5/labels/0185.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0185.txt
# Completed 95.5 KiB/~134.6 KiB (132.9 KiB/s) with ~261 file(s) remaining (calculating...)
# Completed 95.5 KiB/~136.9 KiB (130.4 KiB/s) with ~275 file(s) remaining (calculating...)
# upload: yolov5/labels/0187.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0187.txt
# Completed 95.5 KiB/~136.9 KiB (130.4 KiB/s) with ~274 file(s) remaining (calculating...)
# Completed 95.7 KiB/~136.9 KiB (130.3 KiB/s) with ~274 file(s) remaining (calculating...)
# upload: yolov5/labels/0164.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0164.txt
# Completed 95.7 KiB/~136.9 KiB (130.3 KiB/s) with ~273 file(s) remaining (calculating...)
# Completed 95.7 KiB/~136.9 KiB (129.8 KiB/s) with ~273 file(s) remaining (calculating...)
# upload: yolov5/labels/0189.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0189.txt
# Completed 95.7 KiB/~136.9 KiB (129.8 KiB/s) with ~272 file(s) remaining (calculating...)
# Completed 95.8 KiB/~137.2 KiB (129.4 KiB/s) with ~274 file(s) remaining (calculating...)
# upload: yolov5/labels/0188.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0188.txt
# Completed 95.8 KiB/~137.2 KiB (129.4 KiB/s) with ~273 file(s) remaining (calculating...)
# Completed 95.9 KiB/~137.8 KiB (128.4 KiB/s) with ~277 file(s) remaining (calculating...)
# upload: yolov5/labels/0194.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0194.txt
# Completed 95.9 KiB/~137.8 KiB (128.4 KiB/s) with ~276 file(s) remaining (calculating...)
# Completed 95.9 KiB/~140.3 KiB (126.1 KiB/s) with ~294 file(s) remaining (calculating...)
# upload: yolov5/labels/0198.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0198.txt
# Completed 95.9 KiB/~140.3 KiB (126.1 KiB/s) with ~293 file(s) remaining (calculating...)
# Completed 96.0 KiB/~140.5 KiB (125.6 KiB/s) with ~294 file(s) remaining (calculating...)
# upload: yolov5/labels/0195.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0195.txt
# Completed 96.0 KiB/~140.5 KiB (125.6 KiB/s) with ~293 file(s) remaining (calculating...)
# Completed 96.4 KiB/~140.5 KiB (126.0 KiB/s) with ~293 file(s) remaining (calculating...)
# upload: yolov5/labels/0192.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0192.txt
# Completed 96.4 KiB/~140.5 KiB (126.0 KiB/s) with ~292 file(s) remaining (calculating...)
# Completed 96.6 KiB/~140.6 KiB (125.3 KiB/s) with ~293 file(s) remaining (calculating...)
# upload: yolov5/labels/0190.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0190.txt
# Completed 96.6 KiB/~140.6 KiB (125.3 KiB/s) with ~292 file(s) remaining (calculating...)
# Completed 96.7 KiB/~140.6 KiB (125.2 KiB/s) with ~292 file(s) remaining (calculating...)
# upload: yolov5/labels/0199.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0199.txt
# Completed 96.7 KiB/~140.6 KiB (125.2 KiB/s) with ~291 file(s) remaining (calculating...)
# Completed 96.8 KiB/~140.8 KiB (125.1 KiB/s) with ~293 file(s) remaining (calculating...)
# upload: yolov5/labels/0197.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0197.txt
# Completed 96.8 KiB/~140.8 KiB (125.1 KiB/s) with ~292 file(s) remaining (calculating...)
# Completed 97.1 KiB/~142.2 KiB (123.8 KiB/s) with ~298 file(s) remaining (calculating...)
# upload: yolov5/labels/0200.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0200.txt
# Completed 97.1 KiB/~142.2 KiB (123.8 KiB/s) with ~297 file(s) remaining (calculating...)
# Completed 97.4 KiB/~142.5 KiB (123.5 KiB/s) with ~300 file(s) remaining (calculating...)
# upload: yolov5/labels/0201.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0201.txt
# Completed 97.4 KiB/~142.5 KiB (123.5 KiB/s) with ~299 file(s) remaining (calculating...)
# Completed 97.6 KiB/~142.6 KiB (123.1 KiB/s) with ~300 file(s) remaining (calculating...)
# upload: yolov5/labels/0186.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0186.txt
# Completed 97.6 KiB/~142.6 KiB (123.1 KiB/s) with ~299 file(s) remaining (calculating...)
# Completed 97.7 KiB/~143.0 KiB (122.7 KiB/s) with ~300 file(s) remaining (calculating...)
# upload: yolov5/labels/0202.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0202.txt
# Completed 97.7 KiB/~143.0 KiB (122.7 KiB/s) with ~299 file(s) remaining (calculating...)
# Completed 97.7 KiB/~143.1 KiB (122.5 KiB/s) with ~300 file(s) remaining (calculating...)
# upload: yolov5/labels/0205.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0205.txt
# Completed 97.7 KiB/~143.1 KiB (122.5 KiB/s) with ~299 file(s) remaining (calculating...)
# Completed 97.8 KiB/~143.2 KiB (122.0 KiB/s) with ~300 file(s) remaining (calculating...)
# upload: yolov5/labels/0206.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0206.txt
# Completed 97.8 KiB/~143.2 KiB (122.0 KiB/s) with ~299 file(s) remaining (calculating...)
# Completed 98.2 KiB/~143.2 KiB (122.1 KiB/s) with ~300 file(s) remaining (calculating...)
# upload: yolov5/labels/0203.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0203.txt
# Completed 98.2 KiB/~143.2 KiB (122.1 KiB/s) with ~299 file(s) remaining (calculating...)
# Completed 98.3 KiB/~143.5 KiB (121.6 KiB/s) with ~301 file(s) remaining (calculating...)
# upload: yolov5/labels/0207.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0207.txt
# Completed 98.3 KiB/~143.5 KiB (121.6 KiB/s) with ~300 file(s) remaining (calculating...)
# Completed 98.4 KiB/~147.1 KiB (118.8 KiB/s) with ~322 file(s) remaining (calculating...)
# upload: yolov5/labels/0213.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0213.txt
# Completed 98.4 KiB/~147.1 KiB (118.8 KiB/s) with ~321 file(s) remaining (calculating...)
# Completed 98.6 KiB/~147.1 KiB (118.9 KiB/s) with ~321 file(s) remaining (calculating...)
# upload: yolov5/labels/0212.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0212.txt
# Completed 98.6 KiB/~147.1 KiB (118.9 KiB/s) with ~321 file(s) remaining (calculating...)
# Completed 98.6 KiB/~147.9 KiB (118.1 KiB/s) with ~324 file(s) remaining (calculating...)
# upload: yolov5/labels/0217.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0217.txt
# Completed 98.6 KiB/~147.9 KiB (118.1 KiB/s) with ~323 file(s) remaining (calculating...)
# Completed 98.7 KiB/~147.9 KiB (118.0 KiB/s) with ~323 file(s) remaining (calculating...)
# upload: yolov5/labels/0219.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0219.txt
# Completed 98.7 KiB/~147.9 KiB (118.0 KiB/s) with ~322 file(s) remaining (calculating...)
# Completed 99.0 KiB/~148.4 KiB (117.5 KiB/s) with ~325 file(s) remaining (calculating...)
# upload: yolov5/labels/0211.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0211.txt
# Completed 99.0 KiB/~148.4 KiB (117.5 KiB/s) with ~324 file(s) remaining (calculating...)
# Completed 99.3 KiB/~148.4 KiB (117.7 KiB/s) with ~324 file(s) remaining (calculating...)
# upload: yolov5/labels/0216.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0216.txt
# Completed 99.3 KiB/~148.4 KiB (117.7 KiB/s) with ~323 file(s) remaining (calculating...)
# Completed 99.4 KiB/~148.8 KiB (117.5 KiB/s) with ~325 file(s) remaining (calculating...)
# upload: yolov5/labels/0214.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0214.txt
# Completed 99.4 KiB/~148.8 KiB (117.5 KiB/s) with ~324 file(s) remaining (calculating...)
# Completed 99.5 KiB/~150.5 KiB (115.7 KiB/s) with ~333 file(s) remaining (calculating...)
# upload: yolov5/labels/0223.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0223.txt
# Completed 99.5 KiB/~150.5 KiB (115.7 KiB/s) with ~332 file(s) remaining (calculating...)
# Completed 99.9 KiB/~150.7 KiB (116.0 KiB/s) with ~333 file(s) remaining (calculating...)
# upload: yolov5/labels/0210.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0210.txt
# Completed 99.9 KiB/~150.7 KiB (116.0 KiB/s) with ~332 file(s) remaining (calculating...)
# Completed 99.9 KiB/~150.7 KiB (115.9 KiB/s) with ~332 file(s) remaining (calculating...)
# upload: yolov5/labels/0220.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0220.txt
# Completed 99.9 KiB/~150.7 KiB (115.9 KiB/s) with ~331 file(s) remaining (calculating...)
# Completed 100.0 KiB/~152.1 KiB (114.6 KiB/s) with ~339 file(s) remaining (calculating...)
# upload: yolov5/labels/0225.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/0225.txt
# Completed 100.0 KiB/~152.1 KiB (114.6 KiB/s) with ~338 file(s) remaining (calculating...)
# ...
# Completed 487.5 KiB/496.4 KiB (42.6 KiB/s) with 64 file(s) remaining
# Completed 488.0 KiB/496.4 KiB (42.6 KiB/s) with 64 file(s) remaining
# upload: yolov5/labels/4325.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4325.txt
# Completed 488.0 KiB/496.4 KiB (42.6 KiB/s) with 63 file(s) remaining
# Completed 488.2 KiB/496.4 KiB (42.6 KiB/s) with 63 file(s) remaining
# upload: yolov5/labels/4332.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4332.txt
# Completed 488.2 KiB/496.4 KiB (42.6 KiB/s) with 62 file(s) remaining
# Completed 488.4 KiB/496.4 KiB (42.6 KiB/s) with 62 file(s) remaining
# upload: yolov5/labels/4334.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4334.txt
# Completed 488.4 KiB/496.4 KiB (42.6 KiB/s) with 61 file(s) remaining
# Completed 488.5 KiB/496.4 KiB (42.6 KiB/s) with 61 file(s) remaining
# upload: yolov5/labels/4321.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4321.txt
# Completed 488.5 KiB/496.4 KiB (42.6 KiB/s) with 60 file(s) remaining
# Completed 488.5 KiB/496.4 KiB (42.6 KiB/s) with 60 file(s) remaining
# upload: yolov5/labels/4340.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4340.txt
# Completed 488.5 KiB/496.4 KiB (42.6 KiB/s) with 59 file(s) remaining
# Completed 488.7 KiB/496.4 KiB (42.6 KiB/s) with 59 file(s) remaining
# upload: yolov5/labels/4329.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4329.txt
# Completed 488.7 KiB/496.4 KiB (42.6 KiB/s) with 58 file(s) remaining
# Completed 489.1 KiB/496.4 KiB (42.6 KiB/s) with 58 file(s) remaining
# upload: yolov5/labels/4335.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4335.txt
# Completed 489.1 KiB/496.4 KiB (42.6 KiB/s) with 57 file(s) remaining
# Completed 489.2 KiB/496.4 KiB (42.6 KiB/s) with 57 file(s) remaining
# Completed 489.2 KiB/496.4 KiB (42.6 KiB/s) with 57 file(s) remaining
# upload: yolov5/labels/4343.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4343.txt
# Completed 489.2 KiB/496.4 KiB (42.6 KiB/s) with 56 file(s) remaining
# upload: yolov5/labels/4338.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4338.txt
# Completed 489.2 KiB/496.4 KiB (42.6 KiB/s) with 55 file(s) remaining
# Completed 489.3 KiB/496.4 KiB (42.6 KiB/s) with 55 file(s) remaining
# upload: yolov5/labels/4341.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4341.txt
# Completed 489.3 KiB/496.4 KiB (42.6 KiB/s) with 54 file(s) remaining
# Completed 489.4 KiB/496.4 KiB (42.6 KiB/s) with 54 file(s) remaining
# upload: yolov5/labels/4336.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4336.txt
# Completed 489.4 KiB/496.4 KiB (42.6 KiB/s) with 53 file(s) remaining
# Completed 489.4 KiB/496.4 KiB (42.6 KiB/s) with 53 file(s) remaining
# upload: yolov5/labels/4347.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4347.txt
# Completed 489.4 KiB/496.4 KiB (42.6 KiB/s) with 52 file(s) remaining
# Completed 489.5 KiB/496.4 KiB (42.6 KiB/s) with 52 file(s) remaining
# upload: yolov5/labels/4349.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4349.txt
# Completed 489.5 KiB/496.4 KiB (42.6 KiB/s) with 51 file(s) remaining
# Completed 489.7 KiB/496.4 KiB (42.6 KiB/s) with 51 file(s) remaining
# upload: yolov5/labels/4355.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4355.txt
# Completed 489.7 KiB/496.4 KiB (42.6 KiB/s) with 50 file(s) remaining
# Completed 489.9 KiB/496.4 KiB (42.6 KiB/s) with 50 file(s) remaining
# upload: yolov5/labels/4351.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4351.txt
# Completed 489.9 KiB/496.4 KiB (42.6 KiB/s) with 49 file(s) remaining
# Completed 489.9 KiB/496.4 KiB (42.6 KiB/s) with 49 file(s) remaining
# upload: yolov5/labels/4337.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4337.txt
# Completed 489.9 KiB/496.4 KiB (42.6 KiB/s) with 48 file(s) remaining
# Completed 490.2 KiB/496.4 KiB (42.6 KiB/s) with 48 file(s) remaining
# upload: yolov5/labels/4359.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4359.txt
# Completed 490.2 KiB/496.4 KiB (42.6 KiB/s) with 47 file(s) remaining
# Completed 490.3 KiB/496.4 KiB (42.6 KiB/s) with 47 file(s) remaining
# upload: yolov5/labels/4356.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4356.txt
# Completed 490.3 KiB/496.4 KiB (42.6 KiB/s) with 46 file(s) remaining
# Completed 490.4 KiB/496.4 KiB (42.6 KiB/s) with 46 file(s) remaining
# upload: yolov5/labels/4354.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4354.txt
# Completed 490.4 KiB/496.4 KiB (42.6 KiB/s) with 45 file(s) remaining
# Completed 490.9 KiB/496.4 KiB (42.6 KiB/s) with 45 file(s) remaining
# upload: yolov5/labels/4364.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4364.txt
# Completed 490.9 KiB/496.4 KiB (42.6 KiB/s) with 44 file(s) remaining
# Completed 490.9 KiB/496.4 KiB (42.6 KiB/s) with 44 file(s) remaining
# upload: yolov5/labels/4363.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4363.txt
# Completed 490.9 KiB/496.4 KiB (42.6 KiB/s) with 43 file(s) remaining
# Completed 491.1 KiB/496.4 KiB (42.6 KiB/s) with 43 file(s) remaining
# upload: yolov5/labels/4350.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4350.txt
# Completed 491.1 KiB/496.4 KiB (42.6 KiB/s) with 42 file(s) remaining
# Completed 491.2 KiB/496.4 KiB (42.6 KiB/s) with 42 file(s) remaining
# upload: yolov5/labels/4365.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4365.txt
# Completed 491.2 KiB/496.4 KiB (42.6 KiB/s) with 41 file(s) remaining
# Completed 491.2 KiB/496.4 KiB (42.6 KiB/s) with 41 file(s) remaining
# upload: yolov5/labels/4353.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4353.txt
# Completed 491.2 KiB/496.4 KiB (42.6 KiB/s) with 40 file(s) remaining
# Completed 491.4 KiB/496.4 KiB (42.6 KiB/s) with 40 file(s) remaining
# upload: yolov5/labels/4339.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4339.txt
# Completed 491.4 KiB/496.4 KiB (42.6 KiB/s) with 39 file(s) remaining
# Completed 491.5 KiB/496.4 KiB (42.6 KiB/s) with 39 file(s) remaining
# upload: yolov5/labels/4369.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4369.txt
# Completed 491.5 KiB/496.4 KiB (42.6 KiB/s) with 38 file(s) remaining
# Completed 491.6 KiB/496.4 KiB (42.6 KiB/s) with 38 file(s) remaining
# upload: yolov5/labels/4370.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4370.txt
# Completed 491.6 KiB/496.4 KiB (42.6 KiB/s) with 37 file(s) remaining
# Completed 491.7 KiB/496.4 KiB (42.6 KiB/s) with 37 file(s) remaining
# upload: yolov5/labels/4371.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4371.txt
# Completed 491.7 KiB/496.4 KiB (42.6 KiB/s) with 36 file(s) remaining
# Completed 491.8 KiB/496.4 KiB (42.6 KiB/s) with 36 file(s) remaining
# upload: yolov5/labels/4360.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4360.txt
# Completed 491.8 KiB/496.4 KiB (42.6 KiB/s) with 35 file(s) remaining
# Completed 491.9 KiB/496.4 KiB (42.6 KiB/s) with 35 file(s) remaining
# upload: yolov5/labels/4375.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4375.txt
# Completed 491.9 KiB/496.4 KiB (42.6 KiB/s) with 34 file(s) remaining
# Completed 492.0 KiB/496.4 KiB (42.6 KiB/s) with 34 file(s) remaining
# upload: yolov5/labels/4379.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4379.txt
# Completed 492.0 KiB/496.4 KiB (42.6 KiB/s) with 33 file(s) remaining
# Completed 492.1 KiB/496.4 KiB (42.6 KiB/s) with 33 file(s) remaining
# upload: yolov5/labels/4381.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4381.txt
# Completed 492.1 KiB/496.4 KiB (42.6 KiB/s) with 32 file(s) remaining
# Completed 492.2 KiB/496.4 KiB (42.6 KiB/s) with 32 file(s) remaining
# upload: yolov5/labels/4376.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4376.txt
# Completed 492.2 KiB/496.4 KiB (42.6 KiB/s) with 31 file(s) remaining
# Completed 492.2 KiB/496.4 KiB (42.6 KiB/s) with 31 file(s) remaining
# upload: yolov5/labels/4373.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4373.txt
# Completed 492.2 KiB/496.4 KiB (42.6 KiB/s) with 30 file(s) remaining
# Completed 492.3 KiB/496.4 KiB (42.5 KiB/s) with 30 file(s) remaining
# upload: yolov5/labels/4383.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4383.txt
# Completed 492.3 KiB/496.4 KiB (42.5 KiB/s) with 29 file(s) remaining
# Completed 492.4 KiB/496.4 KiB (42.5 KiB/s) with 29 file(s) remaining
# upload: yolov5/labels/4361.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4361.txt
# Completed 492.4 KiB/496.4 KiB (42.5 KiB/s) with 28 file(s) remaining
# Completed 492.9 KiB/496.4 KiB (42.5 KiB/s) with 28 file(s) remaining
# upload: yolov5/labels/4382.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4382.txt
# Completed 492.9 KiB/496.4 KiB (42.5 KiB/s) with 27 file(s) remaining
# Completed 492.9 KiB/496.4 KiB (42.5 KiB/s) with 27 file(s) remaining
# upload: yolov5/labels/4388.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4388.txt
# Completed 492.9 KiB/496.4 KiB (42.5 KiB/s) with 26 file(s) remaining
# Completed 493.0 KiB/496.4 KiB (42.5 KiB/s) with 26 file(s) remaining
# upload: yolov5/labels/4385.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4385.txt
# Completed 493.0 KiB/496.4 KiB (42.5 KiB/s) with 25 file(s) remaining
# Completed 493.2 KiB/496.4 KiB (42.6 KiB/s) with 25 file(s) remaining
# upload: yolov5/labels/4374.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4374.txt
# Completed 493.2 KiB/496.4 KiB (42.6 KiB/s) with 24 file(s) remaining
# Completed 493.3 KiB/496.4 KiB (42.6 KiB/s) with 24 file(s) remaining
# upload: yolov5/labels/4387.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4387.txt
# Completed 493.3 KiB/496.4 KiB (42.6 KiB/s) with 23 file(s) remaining
# Completed 493.4 KiB/496.4 KiB (42.6 KiB/s) with 23 file(s) remaining
# upload: yolov5/labels/4380.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4380.txt
# Completed 493.4 KiB/496.4 KiB (42.6 KiB/s) with 22 file(s) remaining
# Completed 493.6 KiB/496.4 KiB (42.6 KiB/s) with 22 file(s) remaining
# upload: yolov5/labels/4386.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4386.txt
# Completed 493.6 KiB/496.4 KiB (42.6 KiB/s) with 21 file(s) remaining
# Completed 493.9 KiB/496.4 KiB (42.6 KiB/s) with 21 file(s) remaining
# upload: yolov5/labels/4384.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4384.txt
# Completed 493.9 KiB/496.4 KiB (42.6 KiB/s) with 20 file(s) remaining
# Completed 494.0 KiB/496.4 KiB (42.5 KiB/s) with 20 file(s) remaining
# upload: yolov5/labels/4396.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4396.txt
# Completed 494.0 KiB/496.4 KiB (42.5 KiB/s) with 19 file(s) remaining
# Completed 494.0 KiB/496.4 KiB (42.5 KiB/s) with 19 file(s) remaining
# upload: yolov5/labels/4395.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4395.txt
# Completed 494.0 KiB/496.4 KiB (42.5 KiB/s) with 18 file(s) remaining
# Completed 494.2 KiB/496.4 KiB (42.5 KiB/s) with 18 file(s) remaining
# upload: yolov5/labels/4390.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4390.txt
# Completed 494.2 KiB/496.4 KiB (42.5 KiB/s) with 17 file(s) remaining
# Completed 494.3 KiB/496.4 KiB (42.5 KiB/s) with 17 file(s) remaining
# upload: yolov5/labels/4392.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4392.txt
# Completed 494.3 KiB/496.4 KiB (42.5 KiB/s) with 16 file(s) remaining
# Completed 494.3 KiB/496.4 KiB (42.5 KiB/s) with 16 file(s) remaining
# upload: yolov5/labels/4397.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4397.txt
# Completed 494.3 KiB/496.4 KiB (42.5 KiB/s) with 15 file(s) remaining
# Completed 494.4 KiB/496.4 KiB (42.5 KiB/s) with 15 file(s) remaining
# upload: yolov5/labels/4398.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4398.txt
# Completed 494.4 KiB/496.4 KiB (42.5 KiB/s) with 14 file(s) remaining
# Completed 494.4 KiB/496.4 KiB (42.5 KiB/s) with 14 file(s) remaining
# upload: yolov5/labels/4394.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4394.txt
# Completed 494.4 KiB/496.4 KiB (42.5 KiB/s) with 13 file(s) remaining
# Completed 494.5 KiB/496.4 KiB (42.5 KiB/s) with 13 file(s) remaining
# upload: yolov5/labels/4402.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4402.txt
# Completed 494.5 KiB/496.4 KiB (42.5 KiB/s) with 12 file(s) remaining
# Completed 494.8 KiB/496.4 KiB (42.5 KiB/s) with 12 file(s) remaining
# upload: yolov5/labels/4401.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4401.txt
# Completed 494.8 KiB/496.4 KiB (42.5 KiB/s) with 11 file(s) remaining
# Completed 494.9 KiB/496.4 KiB (42.5 KiB/s) with 11 file(s) remaining
# upload: yolov5/labels/4405.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4405.txt
# Completed 494.9 KiB/496.4 KiB (42.5 KiB/s) with 10 file(s) remaining
# Completed 495.0 KiB/496.4 KiB (42.5 KiB/s) with 10 file(s) remaining
# upload: yolov5/labels/4393.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4393.txt
# Completed 495.0 KiB/496.4 KiB (42.5 KiB/s) with 9 file(s) remaining
# Completed 495.1 KiB/496.4 KiB (42.5 KiB/s) with 9 file(s) remaining
# upload: yolov5/labels/4403.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4403.txt
# Completed 495.1 KiB/496.4 KiB (42.5 KiB/s) with 8 file(s) remaining
# Completed 495.2 KiB/496.4 KiB (42.5 KiB/s) with 8 file(s) remaining
# upload: yolov5/labels/4410.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4410.txt
# Completed 495.2 KiB/496.4 KiB (42.5 KiB/s) with 7 file(s) remaining
# Completed 495.3 KiB/496.4 KiB (42.5 KiB/s) with 7 file(s) remaining
# upload: yolov5/labels/4406.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4406.txt
# Completed 495.3 KiB/496.4 KiB (42.5 KiB/s) with 6 file(s) remaining
# Completed 495.5 KiB/496.4 KiB (42.5 KiB/s) with 6 file(s) remaining
# upload: yolov5/labels/4409.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4409.txt
# Completed 495.5 KiB/496.4 KiB (42.5 KiB/s) with 5 file(s) remaining
# Completed 495.7 KiB/496.4 KiB (42.5 KiB/s) with 5 file(s) remaining
# upload: yolov5/labels/4411.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4411.txt
# Completed 495.7 KiB/496.4 KiB (42.5 KiB/s) with 4 file(s) remaining
# Completed 495.8 KiB/496.4 KiB (42.5 KiB/s) with 4 file(s) remaining
# upload: yolov5/labels/4412.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4412.txt
# Completed 495.8 KiB/496.4 KiB (42.5 KiB/s) with 3 file(s) remaining
# Completed 495.9 KiB/496.4 KiB (42.5 KiB/s) with 3 file(s) remaining
# upload: yolov5/labels/4399.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4399.txt
# Completed 495.9 KiB/496.4 KiB (42.5 KiB/s) with 2 file(s) remaining
# Completed 496.2 KiB/496.4 KiB (42.5 KiB/s) with 2 file(s) remaining
# upload: yolov5/labels/4400.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4400.txt
# Completed 496.2 KiB/496.4 KiB (42.5 KiB/s) with 1 file(s) remaining
# Completed 496.4 KiB/496.4 KiB (42.5 KiB/s) with 1 file(s) remaining
# upload: yolov5/labels/4407.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/yolov5/labels/4407.txt
#
# 2021-05-23 00:58:03,998 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 215
# Billable seconds: 215
