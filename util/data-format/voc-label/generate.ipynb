# %%
import os
import sagemaker

sagemaker_session = sagemaker.Session()

bucket = 'calvinandpogs-ee148'
prefix = 'atrw/detection/out/'

role = sagemaker.get_execution_role()
print(bucket, role)
print(os.getcwd())

# %%
from sagemaker.pytorch import PyTorch

estimator = PyTorch(entry_point='voc_label.py',
                    source_dir='./',
                    framework_version='1.8.0',
                    role=role,
                    py_version='py3',
                    instance_count=1,
                    instance_type='ml.g4dn.xlarge',
                    hyperparameters={})

# %%
estimator.fit({'annot': f's3://{bucket}/atrw/detection/annotations/',
               'train': f's3://{bucket}/atrw/detection/train/'})
# Out:
# 2021-05-22 03:50:02 Starting - Starting the training job...
# 2021-05-22 03:50:29 Starting - Launching requested ML instancesProfilerReport-1621655402: InProgress
# ......
# 2021-05-22 03:51:29 Starting - Preparing the instances for training......
# 2021-05-22 03:52:29 Downloading - Downloading input data......
# 2021-05-22 03:53:29 Training - Downloading the training image...............
# 2021-05-22 03:55:50 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2021-05-22 03:55:47,993 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2021-05-22 03:55:48,015 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2021-05-22 03:55:54,278 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2021-05-22 03:55:54,784 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "annot": "/opt/ml/input/data/annot",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {},
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "annot": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "pytorch-training-2021-05-22-03-50-02-214",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-22-03-50-02-214/source/sourcedir.tar.gz",
#     "module_name": "voc_label",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "voc_label.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={}
# SM_USER_ENTRY_POINT=voc_label.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"annot":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["annot","train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=voc_label
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-22-03-50-02-214/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"annot":"/opt/ml/input/data/annot","train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{},"input_config_dir":"/opt/ml/input/config","input_data_config":{"annot":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"pytorch-training-2021-05-22-03-50-02-214","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-652516965730/pytorch-training-2021-05-22-03-50-02-214/source/sourcedir.tar.gz","module_name":"voc_label","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"voc_label.py"}
# SM_USER_ARGS=[]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_ANNOT=/opt/ml/input/data/annot
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python36.zip:/opt/conda/lib/python3.6:/opt/conda/lib/python3.6/lib-dynload:/opt/conda/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /opt/conda/bin/python3.6 voc_label.py
#
#
# Completed 82.5 KiB/~92.3 KiB (786.5 KiB/s) with ~10 file(s) remaining (calculating...)
# upload: cocoformat/ImageSets/train.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/ImageSets/train.txt
# Completed 82.5 KiB/~92.3 KiB (786.5 KiB/s) with ~9 file(s) remaining (calculating...)
# Completed 91.7 KiB/~92.4 KiB (861.2 KiB/s) with ~10 file(s) remaining (calculating...)
# upload: cocoformat/ImageSets/val.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/ImageSets/val.txt
# Completed 91.7 KiB/~92.4 KiB (861.2 KiB/s) with ~9 file(s) remaining (calculating...)
# Completed 91.8 KiB/~95.9 KiB (646.5 KiB/s) with ~27 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0005.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0005.txt
# Completed 91.8 KiB/~95.9 KiB (646.5 KiB/s) with ~26 file(s) remaining (calculating...)
# Completed 91.8 KiB/~95.9 KiB (637.4 KiB/s) with ~26 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0006.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0006.txt
# Completed 91.8 KiB/~95.9 KiB (637.4 KiB/s) with ~25 file(s) remaining (calculating...)
# Completed 91.9 KiB/~96.2 KiB (609.7 KiB/s) with ~27 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0002.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0002.txt
# Completed 91.9 KiB/~96.2 KiB (609.7 KiB/s) with ~26 file(s) remaining (calculating...)
# Completed 92.0 KiB/~98.3 KiB (547.6 KiB/s) with ~44 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0003.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0003.txt
# Completed 92.0 KiB/~98.3 KiB (547.6 KiB/s) with ~43 file(s) remaining (calculating...)
# Completed 92.1 KiB/~98.3 KiB (541.9 KiB/s) with ~44 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0004.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0004.txt
# Completed 92.1 KiB/~98.3 KiB (541.9 KiB/s) with ~43 file(s) remaining (calculating...)
# Completed 92.2 KiB/~100.7 KiB (512.2 KiB/s) with ~52 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0013.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0013.txt
# Completed 92.2 KiB/~100.7 KiB (512.2 KiB/s) with ~51 file(s) remaining (calculating...)
# Completed 92.3 KiB/~100.7 KiB (508.4 KiB/s) with ~52 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0015.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0015.txt
# Completed 92.3 KiB/~100.7 KiB (508.4 KiB/s) with ~51 file(s) remaining (calculating...)
# Completed 92.4 KiB/~100.7 KiB (504.4 KiB/s) with ~51 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0016.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0016.txt
# Completed 92.4 KiB/~100.7 KiB (504.4 KiB/s) with ~50 file(s) remaining (calculating...)
# Completed 92.5 KiB/~101.6 KiB (487.7 KiB/s) with ~53 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0010.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0010.txt
# Completed 92.5 KiB/~101.6 KiB (487.7 KiB/s) with ~52 file(s) remaining (calculating...)
# Completed 92.6 KiB/~101.6 KiB (482.1 KiB/s) with ~52 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0008.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0008.txt
# Completed 92.6 KiB/~101.6 KiB (482.1 KiB/s) with ~51 file(s) remaining (calculating...)
# Completed 92.7 KiB/~102.9 KiB (448.9 KiB/s) with ~63 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0018.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0018.txt
# Completed 92.7 KiB/~102.9 KiB (448.9 KiB/s) with ~62 file(s) remaining (calculating...)
# Completed 92.8 KiB/~102.9 KiB (446.5 KiB/s) with ~62 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0009.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0009.txt
# Completed 92.8 KiB/~102.9 KiB (446.5 KiB/s) with ~61 file(s) remaining (calculating...)
# Completed 92.8 KiB/~103.0 KiB (435.0 KiB/s) with ~63 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0012.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0012.txt
# Completed 92.8 KiB/~103.0 KiB (435.0 KiB/s) with ~62 file(s) remaining (calculating...)
# Completed 93.0 KiB/~103.4 KiB (427.2 KiB/s) with ~64 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0011.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0011.txt
# Completed 93.0 KiB/~103.4 KiB (427.2 KiB/s) with ~63 file(s) remaining (calculating...)
# Completed 93.2 KiB/~103.5 KiB (424.9 KiB/s) with ~64 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0022.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0022.txt
# Completed 93.2 KiB/~103.5 KiB (424.9 KiB/s) with ~63 file(s) remaining (calculating...)
# Completed 93.8 KiB/~103.5 KiB (425.1 KiB/s) with ~63 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0019.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0019.txt
# Completed 93.8 KiB/~103.5 KiB (425.1 KiB/s) with ~62 file(s) remaining (calculating...)
# Completed 93.9 KiB/~103.5 KiB (421.0 KiB/s) with ~62 file(s) remaining (calculating...)
# Completed 94.2 KiB/~103.5 KiB (420.9 KiB/s) with ~62 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0023.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0023.txt
# Completed 94.2 KiB/~103.5 KiB (420.9 KiB/s) with ~61 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0025.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0025.txt
# Completed 94.2 KiB/~103.5 KiB (420.9 KiB/s) with ~60 file(s) remaining (calculating...)
# Completed 94.3 KiB/~104.0 KiB (408.4 KiB/s) with ~64 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0031.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0031.txt
# Completed 94.3 KiB/~104.0 KiB (408.4 KiB/s) with ~63 file(s) remaining (calculating...)
# Completed 94.6 KiB/~105.9 KiB (382.6 KiB/s) with ~77 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0029.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0029.txt
# Completed 94.6 KiB/~105.9 KiB (382.6 KiB/s) with ~76 file(s) remaining (calculating...)
# Completed 94.6 KiB/~105.9 KiB (379.2 KiB/s) with ~76 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0028.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0028.txt
# Completed 94.6 KiB/~105.9 KiB (379.2 KiB/s) with ~75 file(s) remaining (calculating...)
# Completed 94.7 KiB/~106.4 KiB (369.2 KiB/s) with ~80 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0026.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0026.txt
# Completed 94.7 KiB/~106.4 KiB (369.2 KiB/s) with ~79 file(s) remaining (calculating...)
# Completed 95.0 KiB/~106.5 KiB (367.5 KiB/s) with ~80 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0030.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0030.txt
# Completed 95.0 KiB/~106.5 KiB (367.5 KiB/s) with ~79 file(s) remaining (calculating...)
# Completed 95.1 KiB/~106.6 KiB (362.4 KiB/s) with ~80 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0027.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0027.txt
# Completed 95.1 KiB/~106.6 KiB (362.4 KiB/s) with ~79 file(s) remaining (calculating...)
# Completed 95.2 KiB/~107.3 KiB (353.2 KiB/s) with ~83 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0038.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0038.txt
# Completed 95.2 KiB/~107.3 KiB (353.2 KiB/s) with ~82 file(s) remaining (calculating...)
# Completed 95.3 KiB/~107.6 KiB (350.7 KiB/s) with ~83 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0033.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0033.txt
# Completed 95.3 KiB/~107.6 KiB (350.7 KiB/s) with ~82 file(s) remaining (calculating...)
# Completed 95.9 KiB/~107.9 KiB (345.6 KiB/s) with ~84 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0037.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0037.txt
# Completed 95.9 KiB/~107.9 KiB (345.6 KiB/s) with ~83 file(s) remaining (calculating...)
# Completed 95.9 KiB/~108.0 KiB (341.5 KiB/s) with ~84 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0036.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0036.txt
# Completed 95.9 KiB/~108.0 KiB (341.5 KiB/s) with ~83 file(s) remaining (calculating...)
# Completed 96.0 KiB/~108.1 KiB (336.7 KiB/s) with ~85 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0043.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0043.txt
# Completed 96.0 KiB/~108.1 KiB (336.7 KiB/s) with ~84 file(s) remaining (calculating...)
# Completed 96.1 KiB/~108.2 KiB (334.3 KiB/s) with ~85 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0044.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0044.txt
# Completed 96.1 KiB/~108.2 KiB (334.3 KiB/s) with ~84 file(s) remaining (calculating...)
# Completed 96.3 KiB/~108.3 KiB (331.3 KiB/s) with ~85 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0042.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0042.txt
# Completed 96.3 KiB/~108.3 KiB (331.3 KiB/s) with ~84 file(s) remaining (calculating...)
# Completed 96.4 KiB/~108.8 KiB (323.6 KiB/s) with ~86 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0049.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0049.txt
# Completed 96.4 KiB/~108.8 KiB (323.6 KiB/s) with ~85 file(s) remaining (calculating...)
# Completed 96.5 KiB/~109.0 KiB (321.5 KiB/s) with ~87 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0046.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0046.txt
# Completed 96.5 KiB/~109.0 KiB (321.5 KiB/s) with ~86 file(s) remaining (calculating...)
# Completed 96.6 KiB/~109.0 KiB (319.2 KiB/s) with ~86 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0050.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0050.txt
# Completed 96.6 KiB/~109.0 KiB (319.2 KiB/s) with ~85 file(s) remaining (calculating...)
# Completed 96.7 KiB/~109.4 KiB (312.7 KiB/s) with ~88 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0054.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0054.txt
# Completed 96.7 KiB/~109.4 KiB (312.7 KiB/s) with ~87 file(s) remaining (calculating...)
# Completed 96.8 KiB/~110.2 KiB (308.8 KiB/s) with ~90 file(s) remaining (calculating...)
# Completed 97.0 KiB/~110.2 KiB (308.8 KiB/s) with ~90 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0056.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0056.txt
# Completed 97.0 KiB/~110.2 KiB (308.8 KiB/s) with ~89 file(s) remaining (calculating...)
# Completed 97.1 KiB/~110.3 KiB (307.1 KiB/s) with ~90 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0058.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0058.txt
# Completed 97.1 KiB/~110.3 KiB (307.1 KiB/s) with ~89 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0055.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0055.txt
# Completed 97.1 KiB/~110.3 KiB (307.1 KiB/s) with ~88 file(s) remaining (calculating...)
# Completed 97.3 KiB/~111.1 KiB (296.9 KiB/s) with ~93 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0059.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0059.txt
# Completed 97.3 KiB/~111.1 KiB (296.9 KiB/s) with ~92 file(s) remaining (calculating...)
# Completed 97.6 KiB/~111.9 KiB (290.2 KiB/s) with ~100 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0060.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0060.txt
# Completed 97.6 KiB/~111.9 KiB (290.2 KiB/s) with ~99 file(s) remaining (calculating...)
# Completed 97.7 KiB/~111.9 KiB (289.5 KiB/s) with ~99 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0064.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0064.txt
# Completed 97.7 KiB/~111.9 KiB (289.5 KiB/s) with ~98 file(s) remaining (calculating...)
# Completed 97.9 KiB/~112.9 KiB (287.3 KiB/s) with ~101 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0062.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0062.txt
# Completed 97.9 KiB/~112.9 KiB (287.3 KiB/s) with ~100 file(s) remaining (calculating...)
# Completed 98.0 KiB/~112.9 KiB (285.5 KiB/s) with ~100 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0067.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0067.txt
# Completed 98.0 KiB/~112.9 KiB (285.5 KiB/s) with ~99 file(s) remaining (calculating...)
# Completed 98.1 KiB/~112.9 KiB (283.6 KiB/s) with ~100 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0066.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0066.txt
# Completed 98.1 KiB/~112.9 KiB (283.6 KiB/s) with ~99 file(s) remaining (calculating...)
# Completed 98.1 KiB/~115.6 KiB (265.9 KiB/s) with ~123 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0068.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0068.txt
# Completed 98.1 KiB/~115.6 KiB (265.9 KiB/s) with ~122 file(s) remaining (calculating...)
# Completed 98.2 KiB/~116.2 KiB (264.5 KiB/s) with ~126 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0071.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0071.txt
# Completed 98.2 KiB/~116.2 KiB (264.5 KiB/s) with ~125 file(s) remaining (calculating...)
# Completed 98.3 KiB/~116.2 KiB (263.8 KiB/s) with ~125 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0074.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0074.txt
# Completed 98.3 KiB/~116.2 KiB (263.8 KiB/s) with ~124 file(s) remaining (calculating...)
# Completed 98.3 KiB/~116.2 KiB (263.2 KiB/s) with ~124 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0072.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0072.txt
# Completed 98.3 KiB/~116.2 KiB (263.2 KiB/s) with ~123 file(s) remaining (calculating...)
# Completed 98.4 KiB/~116.6 KiB (259.2 KiB/s) with ~125 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0061.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0061.txt
# Completed 98.4 KiB/~116.6 KiB (259.2 KiB/s) with ~124 file(s) remaining (calculating...)
# Completed 99.1 KiB/~116.6 KiB (260.4 KiB/s) with ~124 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0075.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0075.txt
# Completed 99.1 KiB/~116.6 KiB (260.4 KiB/s) with ~123 file(s) remaining (calculating...)
# Completed 99.2 KiB/~116.6 KiB (259.9 KiB/s) with ~123 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0079.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0079.txt
# Completed 99.2 KiB/~116.6 KiB (259.9 KiB/s) with ~122 file(s) remaining (calculating...)
# Completed 99.3 KiB/~116.6 KiB (259.4 KiB/s) with ~122 file(s) remaining (calculating...)
# Completed 99.4 KiB/~116.6 KiB (259.1 KiB/s) with ~122 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0078.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0078.txt
# Completed 99.4 KiB/~116.6 KiB (259.1 KiB/s) with ~121 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0070.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0070.txt
# Completed 99.4 KiB/~116.7 KiB (259.1 KiB/s) with ~121 file(s) remaining (calculating...)
# Completed 99.4 KiB/~118.0 KiB (245.7 KiB/s) with ~129 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0080.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0080.txt
# Completed 99.4 KiB/~118.0 KiB (245.7 KiB/s) with ~128 file(s) remaining (calculating...)
# Completed 99.5 KiB/~119.8 KiB (239.6 KiB/s) with ~137 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0091.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0091.txt
# Completed 99.5 KiB/~119.8 KiB (239.6 KiB/s) with ~136 file(s) remaining (calculating...)
# Completed 99.6 KiB/~120.1 KiB (238.7 KiB/s) with ~139 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0081.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0081.txt
# Completed 99.6 KiB/~120.1 KiB (238.7 KiB/s) with ~138 file(s) remaining (calculating...)
# Completed 100.1 KiB/~120.1 KiB (238.9 KiB/s) with ~138 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0085.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0085.txt
# Completed 100.1 KiB/~120.1 KiB (238.9 KiB/s) with ~137 file(s) remaining (calculating...)
# Completed 100.1 KiB/~120.5 KiB (238.3 KiB/s) with ~138 file(s) remaining (calculating...)
# Completed 100.2 KiB/~120.5 KiB (238.1 KiB/s) with ~138 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0086.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0086.txt
# Completed 100.2 KiB/~120.5 KiB (238.1 KiB/s) with ~137 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0096.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0096.txt
# Completed 100.2 KiB/~120.5 KiB (238.1 KiB/s) with ~136 file(s) remaining (calculating...)
# Completed 100.9 KiB/~120.5 KiB (238.8 KiB/s) with ~136 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0088.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0088.txt
# Completed 100.9 KiB/~120.5 KiB (238.8 KiB/s) with ~135 file(s) remaining (calculating...)
# Completed 101.0 KiB/~120.5 KiB (237.6 KiB/s) with ~135 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0093.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0093.txt
# Completed 101.0 KiB/~120.5 KiB (237.6 KiB/s) with ~134 file(s) remaining (calculating...)
# Completed 101.7 KiB/~121.3 KiB (233.1 KiB/s) with ~137 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0083.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0083.txt
# Completed 101.7 KiB/~121.3 KiB (233.1 KiB/s) with ~136 file(s) remaining (calculating...)
# Completed 101.8 KiB/~123.3 KiB (226.9 KiB/s) with ~145 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0095.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0095.txt
# Completed 101.8 KiB/~123.3 KiB (226.9 KiB/s) with ~144 file(s) remaining (calculating...)
# Completed 101.9 KiB/~123.9 KiB (225.1 KiB/s) with ~147 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0098.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0098.txt
# Completed 101.9 KiB/~123.9 KiB (225.1 KiB/s) with ~146 file(s) remaining (calculating...)
# Completed 101.9 KiB/~123.9 KiB (224.6 KiB/s) with ~146 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0104.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0104.txt
# Completed 101.9 KiB/~123.9 KiB (224.6 KiB/s) with ~145 file(s) remaining (calculating...)
# Completed 102.0 KiB/~124.0 KiB (222.7 KiB/s) with ~146 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0107.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0107.txt
# Completed 102.0 KiB/~124.0 KiB (222.7 KiB/s) with ~145 file(s) remaining (calculating...)
# Completed 102.1 KiB/~124.0 KiB (222.3 KiB/s) with ~145 file(s) remaining (calculating...)
# Completed 102.1 KiB/~124.0 KiB (222.1 KiB/s) with ~145 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0110.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0110.txt
# Completed 102.1 KiB/~124.0 KiB (222.1 KiB/s) with ~144 file(s) remaining (calculating...)
# Completed 102.2 KiB/~124.0 KiB (221.4 KiB/s) with ~144 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0113.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0113.txt
# Completed 102.2 KiB/~124.1 KiB (221.4 KiB/s) with ~144 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0112.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0112.txt
# Completed 102.2 KiB/~125.1 KiB (221.4 KiB/s) with ~151 file(s) remaining (calculating...)
# Completed 102.6 KiB/~125.3 KiB (217.5 KiB/s) with ~152 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0099.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0099.txt
# Completed 102.6 KiB/~125.3 KiB (217.5 KiB/s) with ~151 file(s) remaining (calculating...)
# Completed 102.6 KiB/~125.3 KiB (216.9 KiB/s) with ~151 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0114.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0114.txt
# Completed 102.6 KiB/~125.3 KiB (216.9 KiB/s) with ~150 file(s) remaining (calculating...)
# Completed 102.8 KiB/~125.3 KiB (215.7 KiB/s) with ~151 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0100.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0100.txt
# Completed 102.8 KiB/~125.6 KiB (215.7 KiB/s) with ~152 file(s) remaining (calculating...)
# Completed 102.9 KiB/~126.4 KiB (209.8 KiB/s) with ~157 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0122.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0122.txt
# Completed 102.9 KiB/~126.4 KiB (209.8 KiB/s) with ~156 file(s) remaining (calculating...)
# Completed 103.0 KiB/~127.4 KiB (206.8 KiB/s) with ~161 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0120.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0120.txt
# Completed 103.0 KiB/~127.4 KiB (206.8 KiB/s) with ~160 file(s) remaining (calculating...)
# Completed 103.0 KiB/~130.2 KiB (202.4 KiB/s) with ~177 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0125.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0125.txt
# Completed 103.0 KiB/~130.4 KiB (202.4 KiB/s) with ~177 file(s) remaining (calculating...)
# Completed 103.2 KiB/~130.4 KiB (201.3 KiB/s) with ~178 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0131.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0131.txt
# Completed 103.2 KiB/~130.4 KiB (201.3 KiB/s) with ~177 file(s) remaining (calculating...)
# Completed 103.2 KiB/~130.4 KiB (201.0 KiB/s) with ~177 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0132.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0132.txt
# Completed 103.2 KiB/~130.4 KiB (201.0 KiB/s) with ~176 file(s) remaining (calculating...)
# Completed 103.3 KiB/~130.6 KiB (200.7 KiB/s) with ~177 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0138.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0138.txt
# Completed 103.3 KiB/~130.6 KiB (200.7 KiB/s) with ~176 file(s) remaining (calculating...)
# Completed 103.5 KiB/~130.6 KiB (200.1 KiB/s) with ~176 file(s) remaining (calculating...)
# Completed 103.8 KiB/~130.6 KiB (200.4 KiB/s) with ~176 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0130.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0130.txt
# Completed 103.8 KiB/~130.6 KiB (200.4 KiB/s) with ~175 file(s) remaining (calculating...)
# Completed 103.9 KiB/~130.6 KiB (200.1 KiB/s) with ~175 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0137.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0137.txt
# Completed 103.9 KiB/~130.6 KiB (200.1 KiB/s) with ~174 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0136.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0136.txt
# Completed 103.9 KiB/~130.7 KiB (200.1 KiB/s) with ~174 file(s) remaining (calculating...)
# Completed 104.0 KiB/~131.3 KiB (195.4 KiB/s) with ~180 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0139.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0139.txt
# Completed 104.0 KiB/~131.3 KiB (195.4 KiB/s) with ~179 file(s) remaining (calculating...)
# Completed 104.2 KiB/~131.6 KiB (192.6 KiB/s) with ~182 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0141.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0141.txt
# Completed 104.2 KiB/~131.6 KiB (192.6 KiB/s) with ~181 file(s) remaining (calculating...)
# Completed 104.2 KiB/~132.4 KiB (190.0 KiB/s) with ~188 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0146.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0146.txt
# Completed 104.2 KiB/~132.4 KiB (190.0 KiB/s) with ~187 file(s) remaining (calculating...)
# Completed 104.3 KiB/~133.6 KiB (188.8 KiB/s) with ~191 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0145.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0145.txt
# Completed 104.3 KiB/~133.6 KiB (188.8 KiB/s) with ~190 file(s) remaining (calculating...)
# Completed 104.5 KiB/~133.7 KiB (188.3 KiB/s) with ~192 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0143.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0143.txt
# Completed 104.5 KiB/~133.7 KiB (188.3 KiB/s) with ~191 file(s) remaining (calculating...)
# Completed 104.5 KiB/~133.7 KiB (186.4 KiB/s) with ~191 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0153.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0153.txt
# Completed 104.5 KiB/~133.7 KiB (186.4 KiB/s) with ~190 file(s) remaining (calculating...)
# Completed 104.6 KiB/~134.3 KiB (186.1 KiB/s) with ~191 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0148.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0148.txt
# Completed 104.6 KiB/~134.3 KiB (186.1 KiB/s) with ~190 file(s) remaining (calculating...)
# Completed 104.7 KiB/~134.3 KiB (185.9 KiB/s) with ~190 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0154.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0154.txt
# Completed 104.7 KiB/~134.3 KiB (185.9 KiB/s) with ~189 file(s) remaining (calculating...)
# Completed 104.7 KiB/~134.3 KiB (185.5 KiB/s) with ~189 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0152.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0152.txt
# Completed 104.7 KiB/~134.3 KiB (185.5 KiB/s) with ~188 file(s) remaining (calculating...)
# Completed 105.1 KiB/~135.1 KiB (182.0 KiB/s) with ~195 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0147.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0147.txt
# Completed 105.1 KiB/~135.1 KiB (182.0 KiB/s) with ~194 file(s) remaining (calculating...)
# Completed 105.3 KiB/~136.9 KiB (179.2 KiB/s) with ~204 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0155.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0155.txt
# Completed 105.3 KiB/~136.9 KiB (179.2 KiB/s) with ~203 file(s) remaining (calculating...)
# Completed 105.4 KiB/~137.1 KiB (178.6 KiB/s) with ~204 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0163.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0163.txt
# Completed 105.4 KiB/~137.1 KiB (178.6 KiB/s) with ~203 file(s) remaining (calculating...)
# Completed 105.5 KiB/~137.2 KiB (178.2 KiB/s) with ~204 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0158.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0158.txt
# Completed 105.5 KiB/~137.2 KiB (178.2 KiB/s) with ~203 file(s) remaining (calculating...)
# Completed 105.6 KiB/~137.4 KiB (177.9 KiB/s) with ~204 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0164.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0164.txt
# Completed 105.6 KiB/~137.4 KiB (177.9 KiB/s) with ~203 file(s) remaining (calculating...)
# Completed 105.7 KiB/~137.6 KiB (175.4 KiB/s) with ~206 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0167.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0167.txt
# Completed 105.7 KiB/~137.6 KiB (175.4 KiB/s) with ~205 file(s) remaining (calculating...)
# Completed 106.0 KiB/~137.6 KiB (175.5 KiB/s) with ~205 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0165.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0165.txt
# Completed 106.0 KiB/~137.6 KiB (175.5 KiB/s) with ~204 file(s) remaining (calculating...)
# Completed 106.1 KiB/~138.0 KiB (175.1 KiB/s) with ~205 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0168.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0168.txt
# Completed 106.1 KiB/~138.0 KiB (175.1 KiB/s) with ~204 file(s) remaining (calculating...)
# Completed 106.2 KiB/~138.0 KiB (174.8 KiB/s) with ~204 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0166.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0166.txt
# Completed 106.2 KiB/~138.0 KiB (174.8 KiB/s) with ~203 file(s) remaining (calculating...)
# Completed 106.4 KiB/~138.1 KiB (173.2 KiB/s) with ~205 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0169.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0169.txt
# Completed 106.4 KiB/~138.1 KiB (173.2 KiB/s) with ~204 file(s) remaining (calculating...)
# Completed 106.4 KiB/~139.6 KiB (170.4 KiB/s) with ~211 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0171.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0171.txt
# Completed 106.4 KiB/~139.6 KiB (170.4 KiB/s) with ~210 file(s) remaining (calculating...)
# Completed 106.5 KiB/~140.5 KiB (167.9 KiB/s) with ~219 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0172.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0172.txt
# Completed 106.5 KiB/~140.5 KiB (167.9 KiB/s) with ~218 file(s) remaining (calculating...)
# Completed 106.8 KiB/~140.7 KiB (167.7 KiB/s) with ~219 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0174.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0174.txt
# Completed 106.8 KiB/~140.7 KiB (167.7 KiB/s) with ~218 file(s) remaining (calculating...)
# Completed 106.9 KiB/~140.7 KiB (167.1 KiB/s) with ~218 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0173.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0173.txt
# Completed 106.9 KiB/~140.7 KiB (167.1 KiB/s) with ~217 file(s) remaining (calculating...)
# Completed 107.0 KiB/~141.2 KiB (165.4 KiB/s) with ~222 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0177.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0177.txt
# Completed 107.0 KiB/~141.2 KiB (165.4 KiB/s) with ~221 file(s) remaining (calculating...)
# Completed 107.2 KiB/~141.2 KiB (165.2 KiB/s) with ~221 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0175.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0175.txt
# Completed 107.2 KiB/~141.2 KiB (165.2 KiB/s) with ~220 file(s) remaining (calculating...)
# Completed 107.4 KiB/~141.5 KiB (164.7 KiB/s) with ~222 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0181.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0181.txt
# Completed 107.4 KiB/~141.5 KiB (164.7 KiB/s) with ~221 file(s) remaining (calculating...)
# Completed 107.5 KiB/~141.7 KiB (163.4 KiB/s) with ~224 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0182.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0182.txt
# Completed 107.5 KiB/~141.7 KiB (163.4 KiB/s) with ~223 file(s) remaining (calculating...)
# Completed 107.8 KiB/~141.7 KiB (163.5 KiB/s) with ~223 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0180.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0180.txt
# Completed 107.8 KiB/~141.7 KiB (163.5 KiB/s) with ~222 file(s) remaining (calculating...)
# Completed 107.9 KiB/~141.7 KiB (163.2 KiB/s) with ~222 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0183.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0183.txt
# Completed 107.9 KiB/~141.7 KiB (163.2 KiB/s) with ~221 file(s) remaining (calculating...)
# Completed 107.9 KiB/~141.7 KiB (162.9 KiB/s) with ~221 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0185.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0185.txt
# Completed 107.9 KiB/~141.7 KiB (162.9 KiB/s) with ~220 file(s) remaining (calculating...)
# Completed 108.1 KiB/~141.9 KiB (162.7 KiB/s) with ~222 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0176.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0176.txt
# Completed 108.1 KiB/~141.9 KiB (162.7 KiB/s) with ~221 file(s) remaining (calculating...)
# Completed 108.1 KiB/~143.8 KiB (158.7 KiB/s) with ~234 file(s) remaining (calculating...)
# Completed 108.2 KiB/~143.8 KiB (158.5 KiB/s) with ~234 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0188.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0188.txt
# Completed 108.2 KiB/~143.8 KiB (158.5 KiB/s) with ~233 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0187.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0187.txt
# Completed 108.2 KiB/~143.8 KiB (158.5 KiB/s) with ~232 file(s) remaining (calculating...)
# Completed 108.3 KiB/~145.0 KiB (156.1 KiB/s) with ~242 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0194.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0194.txt
# Completed 108.3 KiB/~145.0 KiB (156.1 KiB/s) with ~241 file(s) remaining (calculating...)
# Completed 108.4 KiB/~145.5 KiB (155.7 KiB/s) with ~243 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0198.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0198.txt
# Completed 108.4 KiB/~145.5 KiB (155.7 KiB/s) with ~242 file(s) remaining (calculating...)
# Completed 108.5 KiB/~145.5 KiB (155.6 KiB/s) with ~242 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0190.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0190.txt
# Completed 108.5 KiB/~145.5 KiB (155.6 KiB/s) with ~241 file(s) remaining (calculating...)
# Completed 108.6 KiB/~145.9 KiB (153.9 KiB/s) with ~245 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0189.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0189.txt
# Completed 108.6 KiB/~145.9 KiB (153.9 KiB/s) with ~244 file(s) remaining (calculating...)
# Completed 108.6 KiB/~145.9 KiB (153.8 KiB/s) with ~244 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0195.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0195.txt
# Completed 108.6 KiB/~145.9 KiB (153.8 KiB/s) with ~243 file(s) remaining (calculating...)
# Completed 108.9 KiB/~145.9 KiB (153.7 KiB/s) with ~243 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0200.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0200.txt
# Completed 108.9 KiB/~145.9 KiB (153.7 KiB/s) with ~242 file(s) remaining (calculating...)
# Completed 109.3 KiB/~145.9 KiB (154.1 KiB/s) with ~242 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0192.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0192.txt
# Completed 109.3 KiB/~145.9 KiB (154.1 KiB/s) with ~241 file(s) remaining (calculating...)
# Completed 109.4 KiB/~146.0 KiB (153.5 KiB/s) with ~242 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0199.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0199.txt
# Completed 109.4 KiB/~146.0 KiB (153.5 KiB/s) with ~241 file(s) remaining (calculating...)
# Completed 109.5 KiB/~148.7 KiB (149.9 KiB/s) with ~255 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0202.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0202.txt
# Completed 109.5 KiB/~148.7 KiB (149.9 KiB/s) with ~254 file(s) remaining (calculating...)
# Completed 109.8 KiB/~149.0 KiB (149.5 KiB/s) with ~257 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0201.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0201.txt
# Completed 109.8 KiB/~149.0 KiB (149.5 KiB/s) with ~256 file(s) remaining (calculating...)
# Completed 109.9 KiB/~149.0 KiB (149.0 KiB/s) with ~257 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0206.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0206.txt
# Completed 109.9 KiB/~149.0 KiB (149.0 KiB/s) with ~256 file(s) remaining (calculating...)
# Completed 109.9 KiB/~149.0 KiB (148.8 KiB/s) with ~256 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0205.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0205.txt
# Completed 109.9 KiB/~149.0 KiB (148.8 KiB/s) with ~255 file(s) remaining (calculating...)
# Completed 110.4 KiB/~149.4 KiB (148.9 KiB/s) with ~257 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0203.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0203.txt
# Completed 110.4 KiB/~149.4 KiB (148.9 KiB/s) with ~256 file(s) remaining (calculating...)
# Completed 110.4 KiB/~149.4 KiB (148.5 KiB/s) with ~257 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0213.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0213.txt
# Completed 110.4 KiB/~149.4 KiB (148.5 KiB/s) with ~256 file(s) remaining (calculating...)
# Completed 110.5 KiB/~149.4 KiB (148.1 KiB/s) with ~256 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0207.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0207.txt
# Completed 110.5 KiB/~149.4 KiB (148.1 KiB/s) with ~255 file(s) remaining (calculating...)
# Completed 110.6 KiB/~149.4 KiB (147.9 KiB/s) with ~255 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0209.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0209.txt
# Completed 110.6 KiB/~149.4 KiB (147.9 KiB/s) with ~254 file(s) remaining (calculating...)
# Completed 110.9 KiB/~150.0 KiB (146.2 KiB/s) with ~256 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0210.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0210.txt
# Completed 110.9 KiB/~150.0 KiB (146.2 KiB/s) with ~255 file(s) remaining (calculating...)
# Completed 111.2 KiB/~150.1 KiB (145.5 KiB/s) with ~256 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0212.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0212.txt
# Completed 111.2 KiB/~150.1 KiB (145.5 KiB/s) with ~255 file(s) remaining (calculating...)
# Completed 111.2 KiB/~151.5 KiB (143.8 KiB/s) with ~262 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0214.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0214.txt
# Completed 111.2 KiB/~151.5 KiB (143.8 KiB/s) with ~261 file(s) remaining (calculating...)
# Completed 111.3 KiB/~152.1 KiB (143.2 KiB/s) with ~263 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0217.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0217.txt
# Completed 111.3 KiB/~152.1 KiB (143.2 KiB/s) with ~262 file(s) remaining (calculating...)
# Completed 111.4 KiB/~152.1 KiB (143.1 KiB/s) with ~262 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0219.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0219.txt
# Completed 111.4 KiB/~152.1 KiB (143.1 KiB/s) with ~261 file(s) remaining (calculating...)
# Completed 111.4 KiB/~152.2 KiB (142.5 KiB/s) with ~262 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0223.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0223.txt
# Completed 111.4 KiB/~152.2 KiB (142.5 KiB/s) with ~261 file(s) remaining (calculating...)
# Completed 111.5 KiB/~152.4 KiB (141.8 KiB/s) with ~263 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0220.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0220.txt
# Completed 111.5 KiB/~152.4 KiB (141.8 KiB/s) with ~262 file(s) remaining (calculating...)
# Completed 111.8 KiB/~152.4 KiB (141.8 KiB/s) with ~262 file(s) remaining (calculating...)
# upload: cocoformat/labels/train/0216.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/train/0216.txt
# ...
# Completed 500.1 KiB/509.9 KiB (41.8 KiB/s) with 60 file(s) remaining
# upload: cocoformat/labels/val/3609.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3609.txt
# Completed 500.1 KiB/509.9 KiB (41.8 KiB/s) with 59 file(s) remaining
# Completed 500.2 KiB/509.9 KiB (41.8 KiB/s) with 59 file(s) remaining
# upload: cocoformat/labels/val/3536.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3536.txt
# Completed 500.2 KiB/509.9 KiB (41.8 KiB/s) with 58 file(s) remaining
# Completed 500.2 KiB/509.9 KiB (41.8 KiB/s) with 58 file(s) remaining
# Completed 500.5 KiB/509.9 KiB (41.8 KiB/s) with 58 file(s) remaining
# upload: cocoformat/labels/val/3705.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3705.txt
# Completed 500.5 KiB/509.9 KiB (41.8 KiB/s) with 57 file(s) remaining
# Completed 500.7 KiB/509.9 KiB (41.8 KiB/s) with 57 file(s) remaining
# upload: cocoformat/labels/val/3649.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3649.txt
# Completed 500.7 KiB/509.9 KiB (41.8 KiB/s) with 56 file(s) remaining
# Completed 500.8 KiB/509.9 KiB (41.8 KiB/s) with 56 file(s) remaining
# upload: cocoformat/labels/val/3709.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3709.txt
# Completed 500.8 KiB/509.9 KiB (41.8 KiB/s) with 55 file(s) remaining
# upload: cocoformat/labels/val/3696.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3696.txt
# Completed 500.8 KiB/509.9 KiB (41.8 KiB/s) with 54 file(s) remaining
# Completed 501.2 KiB/509.9 KiB (41.9 KiB/s) with 54 file(s) remaining
# upload: cocoformat/labels/val/3585.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3585.txt
# Completed 501.2 KiB/509.9 KiB (41.9 KiB/s) with 53 file(s) remaining
# Completed 501.9 KiB/509.9 KiB (41.9 KiB/s) with 53 file(s) remaining
# upload: cocoformat/labels/val/3706.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3706.txt
# Completed 501.9 KiB/509.9 KiB (41.9 KiB/s) with 52 file(s) remaining
# Completed 502.1 KiB/509.9 KiB (41.9 KiB/s) with 52 file(s) remaining
# upload: cocoformat/labels/val/3776.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3776.txt
# Completed 502.1 KiB/509.9 KiB (41.9 KiB/s) with 51 file(s) remaining
# Completed 502.2 KiB/509.9 KiB (41.8 KiB/s) with 51 file(s) remaining
# upload: cocoformat/labels/val/3711.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3711.txt
# Completed 502.2 KiB/509.9 KiB (41.8 KiB/s) with 50 file(s) remaining
# Completed 502.4 KiB/509.9 KiB (41.8 KiB/s) with 50 file(s) remaining
# upload: cocoformat/labels/val/3728.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3728.txt
# Completed 502.4 KiB/509.9 KiB (41.8 KiB/s) with 49 file(s) remaining
# Completed 502.4 KiB/509.9 KiB (41.9 KiB/s) with 49 file(s) remaining
# upload: cocoformat/labels/val/3772.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3772.txt
# Completed 502.4 KiB/509.9 KiB (41.9 KiB/s) with 48 file(s) remaining
# Completed 502.5 KiB/509.9 KiB (41.8 KiB/s) with 48 file(s) remaining
# upload: cocoformat/labels/val/3940.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3940.txt
# Completed 502.5 KiB/509.9 KiB (41.8 KiB/s) with 47 file(s) remaining
# Completed 502.7 KiB/509.9 KiB (41.9 KiB/s) with 47 file(s) remaining
# upload: cocoformat/labels/val/3787.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3787.txt
# Completed 502.7 KiB/509.9 KiB (41.9 KiB/s) with 46 file(s) remaining
# Completed 502.8 KiB/509.9 KiB (41.9 KiB/s) with 46 file(s) remaining
# upload: cocoformat/labels/val/3794.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3794.txt
# Completed 502.8 KiB/509.9 KiB (41.9 KiB/s) with 45 file(s) remaining
# Completed 502.9 KiB/509.9 KiB (41.9 KiB/s) with 45 file(s) remaining
# upload: cocoformat/labels/val/3873.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3873.txt
# Completed 502.9 KiB/509.9 KiB (41.9 KiB/s) with 44 file(s) remaining
# Completed 503.0 KiB/509.9 KiB (41.9 KiB/s) with 44 file(s) remaining
# upload: cocoformat/labels/val/3848.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3848.txt
# Completed 503.0 KiB/509.9 KiB (41.9 KiB/s) with 43 file(s) remaining
# Completed 503.0 KiB/509.9 KiB (41.9 KiB/s) with 43 file(s) remaining
# upload: cocoformat/labels/val/3891.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3891.txt
# Completed 503.0 KiB/509.9 KiB (41.9 KiB/s) with 42 file(s) remaining
# Completed 503.1 KiB/509.9 KiB (41.8 KiB/s) with 42 file(s) remaining
# upload: cocoformat/labels/val/3726.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3726.txt
# Completed 503.1 KiB/509.9 KiB (41.8 KiB/s) with 41 file(s) remaining
# Completed 503.2 KiB/509.9 KiB (41.8 KiB/s) with 41 file(s) remaining
# upload: cocoformat/labels/val/4010.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4010.txt
# Completed 503.2 KiB/509.9 KiB (41.8 KiB/s) with 40 file(s) remaining
# Completed 503.3 KiB/509.9 KiB (41.8 KiB/s) with 40 file(s) remaining
# upload: cocoformat/labels/val/4026.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4026.txt
# Completed 503.3 KiB/509.9 KiB (41.8 KiB/s) with 39 file(s) remaining
# Completed 503.4 KiB/509.9 KiB (41.8 KiB/s) with 39 file(s) remaining
# upload: cocoformat/labels/val/3957.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3957.txt
# Completed 503.4 KiB/509.9 KiB (41.8 KiB/s) with 38 file(s) remaining
# Completed 503.5 KiB/509.9 KiB (41.8 KiB/s) with 38 file(s) remaining
# upload: cocoformat/labels/val/4039.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4039.txt
# Completed 503.5 KiB/509.9 KiB (41.8 KiB/s) with 37 file(s) remaining
# Completed 503.7 KiB/509.9 KiB (41.8 KiB/s) with 37 file(s) remaining
# upload: cocoformat/labels/val/3798.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3798.txt
# Completed 503.7 KiB/509.9 KiB (41.8 KiB/s) with 36 file(s) remaining
# Completed 503.9 KiB/509.9 KiB (41.8 KiB/s) with 36 file(s) remaining
# upload: cocoformat/labels/val/4052.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4052.txt
# Completed 503.9 KiB/509.9 KiB (41.8 KiB/s) with 35 file(s) remaining
# Completed 504.1 KiB/509.9 KiB (41.8 KiB/s) with 35 file(s) remaining
# upload: cocoformat/labels/val/3967.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3967.txt
# Completed 504.1 KiB/509.9 KiB (41.8 KiB/s) with 34 file(s) remaining
# Completed 504.3 KiB/509.9 KiB (41.8 KiB/s) with 34 file(s) remaining
# upload: cocoformat/labels/val/3934.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3934.txt
# Completed 504.3 KiB/509.9 KiB (41.8 KiB/s) with 33 file(s) remaining
# Completed 504.4 KiB/509.9 KiB (41.8 KiB/s) with 33 file(s) remaining
# upload: cocoformat/labels/val/4103.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4103.txt
# Completed 504.4 KiB/509.9 KiB (41.8 KiB/s) with 32 file(s) remaining
# Completed 504.7 KiB/509.9 KiB (41.8 KiB/s) with 32 file(s) remaining
# upload: cocoformat/labels/val/4013.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4013.txt
# Completed 504.7 KiB/509.9 KiB (41.8 KiB/s) with 31 file(s) remaining
# Completed 504.8 KiB/509.9 KiB (41.8 KiB/s) with 31 file(s) remaining
# upload: cocoformat/labels/val/4074.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4074.txt
# Completed 504.8 KiB/509.9 KiB (41.8 KiB/s) with 30 file(s) remaining
# Completed 504.9 KiB/509.9 KiB (41.8 KiB/s) with 30 file(s) remaining
# upload: cocoformat/labels/val/4085.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4085.txt
# Completed 504.9 KiB/509.9 KiB (41.8 KiB/s) with 29 file(s) remaining
# Completed 505.0 KiB/509.9 KiB (41.8 KiB/s) with 29 file(s) remaining
# upload: cocoformat/labels/val/4149.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4149.txt
# Completed 505.0 KiB/509.9 KiB (41.8 KiB/s) with 28 file(s) remaining
# Completed 505.0 KiB/509.9 KiB (41.8 KiB/s) with 28 file(s) remaining
# upload: cocoformat/labels/val/4121.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4121.txt
# Completed 505.0 KiB/509.9 KiB (41.8 KiB/s) with 27 file(s) remaining
# Completed 505.3 KiB/509.9 KiB (41.8 KiB/s) with 27 file(s) remaining
# upload: cocoformat/labels/val/3968.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/3968.txt
# Completed 505.3 KiB/509.9 KiB (41.8 KiB/s) with 26 file(s) remaining
# Completed 505.5 KiB/509.9 KiB (41.8 KiB/s) with 26 file(s) remaining
# upload: cocoformat/labels/val/4080.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4080.txt
# Completed 505.5 KiB/509.9 KiB (41.8 KiB/s) with 25 file(s) remaining
# Completed 505.5 KiB/509.9 KiB (41.8 KiB/s) with 25 file(s) remaining
# upload: cocoformat/labels/val/4077.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4077.txt
# Completed 505.5 KiB/509.9 KiB (41.8 KiB/s) with 24 file(s) remaining
# Completed 505.6 KiB/509.9 KiB (41.8 KiB/s) with 24 file(s) remaining
# upload: cocoformat/labels/val/4173.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4173.txt
# Completed 505.6 KiB/509.9 KiB (41.8 KiB/s) with 23 file(s) remaining
# Completed 506.1 KiB/509.9 KiB (41.8 KiB/s) with 23 file(s) remaining
# upload: cocoformat/labels/val/4185.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4185.txt
# Completed 506.1 KiB/509.9 KiB (41.8 KiB/s) with 22 file(s) remaining
# Completed 506.2 KiB/509.9 KiB (41.8 KiB/s) with 22 file(s) remaining
# upload: cocoformat/labels/val/4117.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4117.txt
# Completed 506.2 KiB/509.9 KiB (41.8 KiB/s) with 21 file(s) remaining
# Completed 506.3 KiB/509.9 KiB (41.8 KiB/s) with 21 file(s) remaining
# upload: cocoformat/labels/val/4174.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4174.txt
# Completed 506.3 KiB/509.9 KiB (41.8 KiB/s) with 20 file(s) remaining
# Completed 506.4 KiB/509.9 KiB (41.8 KiB/s) with 20 file(s) remaining
# upload: cocoformat/labels/val/4184.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4184.txt
# Completed 506.4 KiB/509.9 KiB (41.8 KiB/s) with 19 file(s) remaining
# Completed 506.6 KiB/509.9 KiB (41.8 KiB/s) with 19 file(s) remaining
# upload: cocoformat/labels/val/4193.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4193.txt
# Completed 506.6 KiB/509.9 KiB (41.8 KiB/s) with 18 file(s) remaining
# Completed 506.6 KiB/509.9 KiB (41.8 KiB/s) with 18 file(s) remaining
# upload: cocoformat/labels/val/4216.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4216.txt
# Completed 506.6 KiB/509.9 KiB (41.8 KiB/s) with 17 file(s) remaining
# Completed 507.3 KiB/509.9 KiB (41.8 KiB/s) with 17 file(s) remaining
# upload: cocoformat/labels/val/4122.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4122.txt
# Completed 507.3 KiB/509.9 KiB (41.8 KiB/s) with 16 file(s) remaining
# Completed 507.4 KiB/509.9 KiB (41.9 KiB/s) with 16 file(s) remaining
# upload: cocoformat/labels/val/4233.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4233.txt
# Completed 507.4 KiB/509.9 KiB (41.9 KiB/s) with 15 file(s) remaining
# Completed 507.5 KiB/509.9 KiB (41.8 KiB/s) with 15 file(s) remaining
# upload: cocoformat/labels/val/4279.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4279.txt
# Completed 507.5 KiB/509.9 KiB (41.8 KiB/s) with 14 file(s) remaining
# Completed 507.6 KiB/509.9 KiB (41.8 KiB/s) with 14 file(s) remaining
# upload: cocoformat/labels/val/4283.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4283.txt
# Completed 507.6 KiB/509.9 KiB (41.8 KiB/s) with 13 file(s) remaining
# Completed 507.8 KiB/509.9 KiB (41.8 KiB/s) with 13 file(s) remaining
# upload: cocoformat/labels/val/4239.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4239.txt
# Completed 507.8 KiB/509.9 KiB (41.8 KiB/s) with 12 file(s) remaining
# Completed 508.0 KiB/509.9 KiB (41.8 KiB/s) with 12 file(s) remaining
# upload: cocoformat/labels/val/4263.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4263.txt
# Completed 508.0 KiB/509.9 KiB (41.8 KiB/s) with 11 file(s) remaining
# Completed 508.1 KiB/509.9 KiB (41.8 KiB/s) with 11 file(s) remaining
# upload: cocoformat/labels/val/4303.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4303.txt
# Completed 508.1 KiB/509.9 KiB (41.8 KiB/s) with 10 file(s) remaining
# Completed 508.2 KiB/509.9 KiB (41.8 KiB/s) with 10 file(s) remaining
# upload: cocoformat/labels/val/4304.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4304.txt
# Completed 508.2 KiB/509.9 KiB (41.8 KiB/s) with 9 file(s) remaining
# Completed 508.2 KiB/509.9 KiB (41.8 KiB/s) with 9 file(s) remaining
# upload: cocoformat/labels/val/4349.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4349.txt
# Completed 508.2 KiB/509.9 KiB (41.8 KiB/s) with 8 file(s) remaining
# Completed 508.5 KiB/509.9 KiB (41.8 KiB/s) with 8 file(s) remaining
# upload: cocoformat/labels/val/4286.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4286.txt
# Completed 508.5 KiB/509.9 KiB (41.8 KiB/s) with 7 file(s) remaining
# Completed 508.7 KiB/509.9 KiB (41.8 KiB/s) with 7 file(s) remaining
# upload: cocoformat/labels/val/4350.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4350.txt
# Completed 508.7 KiB/509.9 KiB (41.8 KiB/s) with 6 file(s) remaining
# Completed 508.8 KiB/509.9 KiB (41.8 KiB/s) with 6 file(s) remaining
# upload: cocoformat/labels/val/4351.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4351.txt
# Completed 508.8 KiB/509.9 KiB (41.8 KiB/s) with 5 file(s) remaining
# Completed 508.9 KiB/509.9 KiB (41.8 KiB/s) with 5 file(s) remaining
# upload: cocoformat/labels/val/4385.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4385.txt
# Completed 508.9 KiB/509.9 KiB (41.8 KiB/s) with 4 file(s) remaining
# Completed 509.3 KiB/509.9 KiB (41.9 KiB/s) with 4 file(s) remaining
# upload: cocoformat/labels/val/4400.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4400.txt
# Completed 509.3 KiB/509.9 KiB (41.9 KiB/s) with 3 file(s) remaining
# Completed 509.5 KiB/509.9 KiB (41.9 KiB/s) with 3 file(s) remaining
# upload: cocoformat/labels/val/4355.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4355.txt
# Completed 509.5 KiB/509.9 KiB (41.9 KiB/s) with 2 file(s) remaining
# Completed 509.6 KiB/509.9 KiB (41.9 KiB/s) with 2 file(s) remaining
# upload: cocoformat/labels/val/4219.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4219.txt
# Completed 509.6 KiB/509.9 KiB (41.9 KiB/s) with 1 file(s) remaining
# Completed 509.9 KiB/509.9 KiB (41.9 KiB/s) with 1 file(s) remaining
# upload: cocoformat/labels/val/4401.txt to s3://calvinandpogs-ee148/atrw/detection/annotations/cocoformat/labels/val/4401.txt
#
# 2021-05-22 03:56:08,708 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2021-05-22 03:56:30 Uploading - Uploading generated training model
# 2021-05-22 03:56:30 Completed - Training job completed
# ProfilerReport-1621655402: NoIssuesFound
# Training seconds: 227
# Billable seconds: 227

# %%
# Out:
# WARNING:sagemaker.deprecations:The function delete_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
